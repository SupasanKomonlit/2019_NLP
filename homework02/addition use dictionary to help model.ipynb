# %% [markdown]
# This file will learn follow reference https://towardsdatascience.com/named-entity-recognition-ner-meeting-industrys-requirement-by-applying-state-of-the-art-deep-698d2b3b4ede

# %%
def read_all_line( directory , file ):
    file = open( directory + "/" + file , "r" , encoding="utf-8" )
    contents = file.read()
    return contents

# %% [raw]
# I at this part to read information about dictionay to hope it will help you about data befor train data

# %%
dictionary_directory = "dictionary_directory"
dictionary = {
    "per_front" : read_all_line( dictionary_directory , "clue front.txt").split('\n')
}

# %%
def check_dictionary( word ):
    result_have = False
    result_tag = "O"
    for key in dictionary.keys():
        if( word in dictionary[ key ] ):
            result_have = True
            result_tag = key
            break
    return result_have , result_tag

# %%
dictionary
# Out:
# {'per_front': ['จอมพลอากาศ',
#   'พลอากาศเอก',
#   'พล.อ.อ.',
#   'พลอากาศโท',
#   'พล.อ.ท.',
#   'พลอากาศตรี',
#   'พล.อ.ต.',
#   'นาวาอากาศเอก',
#   'น.อ.',
#   'นาวาอากาศโท',
#   'น.ท.',
#   'นาวาอากาศตรี',
#   'น.ต.',
#   'เรืออากาศเอก',
#   'ร.อ.',
#   'เรืออากาศโท',
#   'ร.ท.',
#   'เรืออากาศตรี',
#   'ร.ต.',
#   'พันจ่าอากาศเอก',
#   'พ.อ.อ.',
#   'พันจ่าอากาศโท',
#   'พ.อ.ท.',
#   'พันจ่าอากาศตรี',
#   'พ.อ.ต.',
#   'จ่าอากาศเอก',
#   'จ.อ.',
#   'จ่าอากาศโท',
#   'จ.ท.',
#   'จ่าอากาศตรี',
#   'จ.ต.',
#   'พลทหาร',
#   'พลฯ',
#   'นักเรียนนายเรืออากาศ',
#   'นักเรียนจ่าอากาศ',
#   'จอมพล',
#   'พลเอก',
#   'พล.อ.',
#   'พลโท',
#   'พล.ท.',
#   'พลตรี',
#   'พล.ต.',
#   'พันเอก',
#   'พ.อ.',
#   'พันโท',
#   'พ.ท.',
#   'พันตรี',
#   'พ.ต.',
#   'ร้อยเอก',
#   'ร.อ.',
#   'ร้อยโท',
#   'ร.ท.',
#   'ร้อยตรี',
#   'ร.ต.',
#   'จ่าสิบเอก',
#   'จ.ส.อ.',
#   'จ่าสิบโท',
#   'จ.ส.ท.',
#   'จ่าสิบตรี',
#   'จ.ส.ต.',
#   'สิบเอก',
#   'ส.อ.',
#   'สิบโท',
#   'ส.ท.',
#   'สิบตรี',
#   'ส.ต.',
#   'พลทหาร',
#   'พลฯ',
#   'นักเรียนนายร้อย',
#   'นักเรียนนายสิบทหารบก',
#   'จอมพลเรือ',
#   'พลเรือเอก',
#   'พล.ร.อ.',
#   'พลเรือโท',
#   'พล.ร.ท.',
#   'พลเรือตรี',
#   ' พล.ร.ต.',
#   'นาวาเอก',
#   'น.อ. ร.น.',
#   'นาวาโท',
#   'น.ท. ร.น.',
#   'นาวาตรี',
#   'น.ต. ร.น.',
#   'เรือเอก',
#   'ร.อ. ร.น.',
#   'เรือโท',
#   'ร.ท. ร.น.',
#   'เรือตรี',
#   'ร.ต. ร.น.',
#   'พันจ่าเอก',
#   'พ.จ.อ.',
#   'พันจ่าโท',
#   'พ.จ.ท.',
#   'พันจ่าตรี',
#   'พ.จ.ต.',
#   'จ่าเอก',
#   'จ.อ.',
#   'จ่าโท',
#   'จ.ท.',
#   'จ่าตรี',
#   'จ.ต.',
#   'พลทหาร',
#   'Seaman พลฯ',
#   'นักเรียนนายเรือ',
#   'นักเรียนจ่าทหารเรือ',
#   'พลตำรวจเอก',
#   'พล.ต.อ.',
#   'พลตำรวจโท',
#   'พล.ต.ท.',
#   'พลตำรวจตรี',
#   'พล.ต.ต.',
#   'พันตำรวจเอก',
#   'พ.ต.อ.',
#   'พันตำรวจโท',
#   'พ.ต.ท.',
#   'พันตำรวจตรี',
#   'พ.ต.ต.',
#   'ร้อยตำรวจเอก',
#   'ร.ต.อ.',
#   'ร้อยตำรวจโท',
#   'ร.ต.ท.',
#   'ร้อยตำรวจตรี',
#   'ร.ต.ต.',
#   'นายดาบตำรวจ',
#   'ด.ต.',
#   'จ่าสิบตำรวจ',
#   'จ.ส.ต.',
#   'สิบตำรวจเอก',
#   'ส.ต.อ.',
#   'สิบตำรวจโท',
#   'ส.ต.ท.',
#   'สิบตำรวจตรี',
#   'ส.ต.ต.',
#   'พลตำรวจ',
#   'พลฯ',
#   'จ่า',
#   'ผู้พัน',
#   'ผู้กอง',
#   'สารวัตร',
#   'หมวด',
#   'ผู้หมวด',
#   'นาย',
#   'นางสาว',
#   'น.ส.',
#   'นาง',
#   'เด็กชาย',
#   'ด.ช.',
#   'เด็กหญิง',
#   'ด.ญ.',
#   'ท่าน',
#   'ชื่อ',
#   'คุณ',
#   'คุณหญิง',
#   'คุณนาย',
#   'นายแพทย์',
#   'แพทย์หญิง',
#   'ทันตแพทย์',
#   'ทันตแพทย์หญิง',
#   'สัตวแพทย์',
#   'นายสัตวแพทย์',
#   'สัตวแพทย์หญิง',
#   'ศาสตราจารย์',
#   'ศ.',
#   'ศาสตราจารย์ ดอกเตอร์',
#   'ศ. ดร.',
#   'รองศาสตราจารย์',
#   'รศ.',
#   'รองศาสตราจารย์ ดอกเตอร์',
#   'รศ. ดร.',
#   'ผู้ช่วยศาสตรจารย์',
#   'ผศ.',
#   'ผู้ช่วยศาสตราจารย์ ดอกเตอร์',
#   'ผศ. ดร.',
#   'ดอกเตอร์',
#   'ดร.',
#   'อาจารย์',
#   'อ.',
#   'ฯพณฯ',
#   'เสธ.',
#   'บิ๊ก',
#   'เสี่ย',
#   'พระบาทสมเด็จพระเจ้าอยู่หัว',
#   'สมเด็จพระบรมราชินีนาถ',
#   'สมเด็จพระนางเจ้าฯ',
#   'พระนางเจ้า',
#   'สมเด็จพระนางเจ้า',
#   'พระอัครชายาเธอ',
#   'สมเด็จพระราชินี',
#   'สมเด็จพระราชชนนี',
#   'สมเด็จพระ',
#   'สมเด็จพระสยามบรมราชกุมารี',
#   'สมเด็จเจ้าฟ้า',
#   'พระเจ้าบรมวงศ์เธอ พระองค์เจ้า',
#   'พระบรมวงศ์เธอ',
#   'สมเด็จพระเจ้าบรมวงศ์เธอ',
#   'พระเจ้าบรมวงศ์เธอ',
#   'พระเจ้าวรวงศ์เธอ พระองค์เจ้า',
#   'พระวรวงศ์เธอ พระองค์เจ้า',
#   'พระองค์เจ้า',
#   'หม่อมเจ้า',
#   'ม.จ.',
#   'หม่อมราชวงศ์',
#   'ม.ร.ว.',
#   'หม่อมหลวง',
#   'ม.ล.',
#   'เจ้าจอม',
#   'หม่อม',
#   'เจ้าจอมมารดา',
#   'พระชายา',
#   'พระวรชายา',
#   'ท่านชาย',
#   'ท่านหญิง',
#   'คุณชาย',
#   'คุณหญิง',
#   'สมเด็จพระเจ้าพี่นางเธอ',
#   'พระเจ้าพี่นางเธอ',
#   'สมเด็จพระเจ้าพี่ยาเธอ',
#   'พระเจ้าพี่ยาเธอ',
#   'สมเด็จพระเจ้าน้องนางเธอ',
#   'พระเจ้าน้องนางเธอ',
#   'สมเด็จพระเจ้าน้องยาเธอ',
#   'พระเจ้าน้องยาเธอ',
#   'สมเด็จพระเจ้าภคินีเธอ',
#   'สมเด็จพระเจ้าลูกยาเธอ',
#   'สมเด็จพระเจ้าลูกเธอ',
#   'สมเด็จ',
#   'กรมพระยา',
#   'สมเด็จพระสังฆราช',
#   'สมเด็จพระสังฆราชเจ้า',
#   'สมเด็จพระมหาสมณเจ้า',
#   'สมเด็จพระญาณสังวร',
#   'สมเด็จพระธีรญาณมุนี',
#   'สมเด็จพระพุทธโฆษาจารย์',
#   'สมเด็จพระมหาวีรวงศ์',
#   'สมเด็จพระวันรัต',
#   'สมเด็จพระพุทธาจารย์',
#   'พระพิมลธรรม',
#   'พระธรรมวโรดม',
#   'พระวิสุทธาธิบดี',
#   'พระพุทธพจน์วราภรณ์',
#   'พระพุทธิวงศมุนี',
#   'พระญาณวโรดม',
#   'พระพรหมคุณาภรณ์',
#   'พระพรหมมุนี',
#   'พระธรรมปัญญาจารย์',
#   'พระวิสุทธิวงศ์',
#   'พระอุบาลีคุณูปมาจารย์',
#   'พระศาสนโสภณ',
#   'พระราชาคณะ',
#   'สมเด็จพระราชาคณะ',
#   'รองสมเด็จพระราชาคณะ',
#   'เจ้าคุณ',
#   'ท่านเจ้าคุณ',
#   'ธรรม',
#   'เทพ',
#   'ราช',
#   'พระราชาคณะเจ้าคณะรอง',
#   'พระราชาคณะชั้นธรรม',
#   'พระราชาคณะชั้นเทพ',
#   'พระราชาคณะชั้นราช',
#   'พระราชาคณะชั้นสามัญ',
#   'พระครูชั้นพิเศษ',
#   'พระครูชั้นเอก',
#   'พระครูชั้นโท',
#   'พระครูชั้นตรี',
#   'พระครูชั้นสามัญ',
#   'พระครูปลัด',
#   'พระครูวินัยธร',
#   'พระครูธรรมธร',
#   'พระครูปลัด',
#   'พระครู',
#   'พระ',
#   'พระมหา',
#   'สามเณร',
#   'เจ้าอธิการ',
#   'พระราช',
#   'หลวงพ่อ',
#   'หลวงตา',
#   'หลวงปู่',
#   'หลวงอา',
#   'หลวงลุง',
#   'จร.',
#   'เจ้าอาวาสวัดราษฎร์',
#   'รจร.',
#   'รองเจ้าอาวาสวัดราษฎร์',
#   'ผจร.',
#   ' ผู้ช่วยเจ้าอาวาสวัดราษฎร์',
#   'จล.',
#   'เจ้าอาวาสพระอารามหลวง',
#   'รจล.',
#   'รองเจ้าอาวาสพระอารามหลวง',
#   'ผจล.',
#   'ผู้ช่วยเจ้าอาวาสพระอารามหลวง',
#   'จต.',
#   'เจ้าคณะตำบล',
#   'รจต.',
#   'รองเจ้าคณะตำบล',
#   'จอ.',
#   'เจ้าคณะอำเภอ',
#   'รจอ.',
#   'รองเจ้าคณะอำเภอ',
#   'จภ.',
#   'เจ้าคณะภาค',
#   'รจภ.',
#   'รองเจ้าคณะภาค',
#   'จญ.',
#   'เจ้าคณะใหญ่',
#   'จร. ชต.',
#   'เจ้าอาวาสวัดราษฎร์ ชั้นตรี',
#   'จร. ชท.',
#   'เจ้าอาวาสวัดราษฎร์ ชั้นโท',
#   'จร. ชท. วิ.',
#   'เจ้าอาวาสวัดราษฎร์ ชั้นโท ฝ่ายวิปัสสนา',
#   'จร. ชอ.',
#   'เจ้าอาวาสวัดราษฎร์ ชั้นเอก',
#   'รจร.',
#   'รองเจ้าอาวาสวัดราษฎร์',
#   'ผจร.',
#   'ผู้ช่วยเจ้าอาวาสวัดราษฎร์',
#   'ทผจล. ชท.',
#   'เทียบผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นโท',
#   'ทผจล. ชอ.',
#   'เทียบผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นเอก',
#   'ทผจล. ชอ. วิ.',
#   'เทียบผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นเอก ฝ่ายวิปัสสนาธุระ',
#   'ทผจล. ชพ.',
#   'เทียบผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นพิเศษ',
#   'จล. ชต.',
#   'เจ้าอาวาสพระอารามหลวง ชั้นตรี',
#   'จล. ชต. วิ.',
#   'เจ้าอาวาสพระอารามหลวง ชั้นตรี ฝ่ายวิปัสสนาธุระ',
#   'จล. ชท.',
#   'เจ้าอาวาสพระอารามหลวง ชั้นโท',
#   'จล. ชอ.',
#   'เจ้าอาวาสพระอารามหลวง ชั้นเอก',
#   'รจล. ชต.',
#   'รองเจ้าอาวาสพระอารามหลวง ชั้นโตรี',
#   'รจล. ชท.',
#   'รองเจ้าอาวาสพระอารามหลวง ชั้นโท',
#   'รจล. ชท. วิ.',
#   'รองเจ้าอาวาสพระอารามหลวง ชั้นโท ฝ่ายวิปัสสนาธุระ',
#   'รจล. ชอ.',
#   'รองเจ้าอาวาสพระอารามหลวง ชั้นเอก',
#   'ผจล. ชท.',
#   'ผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นโท',
#   'ผจล. ชอ.',
#   'ผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นเอก',
#   'ผจล. ชอ. วิ.',
#   'ผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นเอก ฝ่ายวิปัสสนาธุระ',
#   'ผจล. ชพ.',
#   'ผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นพิเศษ',
#   'จอ. ชท.',
#   'เจ้าคณะอำเภอ ชั้นโท',
#   'จอ. ชอ.',
#   'เจ้าคณะอำเภอ ชั้นเอก',
#   'จอ. ชพ.',
#   'เจ้าคณะอำเภอ ชั้นพิเศษ',
#   'รจอ. ชท.',
#   'รองเจ้าคณะอำเภอ ชั้นโท',
#   'รจอ. ชอ.',
#   'รองเจ้าคณะอำเภอ ชั้นเอก',
#   'รจอ. ชอ. วิ.',
#   'รองเจ้าคณะอำเภอ ชั้นเอก ฝ่ายวิปัสสนาธุระ',
#   'จจ. ชอ.',
#   'เจ้าคณะจังหวัด ชั้นเอก',
#   'จจ. ชท.',
#   'เจ้าคณะจังหวัด ชั้นโท (สังฆปาโมกข์)',
#   'เจ้าคณะจังหวัด ชั้นโท',
#   'รจจ.',
#   'รองเจ้าคณะจังหวัด',
#   'ชพ.',
#   'พระครูสัญญาบัตรชั้นพิเศษ',
#   'ผจล. ชพ.',
#   'ผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นพิเศษ',
#   'ทผจล. ชพ.',
#   'เทียบผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นพิเศษ',
#   'จอ. ชพ.',
#   'เจ้าคณะอำเภอ ชั้นพิเศษ',
#   'วิ.',
#   'พระครูสัญญาบัตรฝ่ายวิปัสสนาธุระ',
#   'จร. ชท. วิ.',
#   'เจ้าอาวาสวัดราษฎร์ ชั้นโท ฝ่ายวิปัสสนาธุระ',
#   'จต. ชอ. วิ.',
#   'เจ้าคณะตำบล ชั้นเอก ฝ่ายวิปัสสนาธุระ',
#   'รจอ. ชอ. วิ.',
#   'รองเจ้าคณะอำเภอ ชั้นเอก ฝ่ายวิปัสสนาธุระ',
#   'ทผจล. ชอ. วิ.',
#   'เทียบผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นเอก ฝ่ายวิปัสสนาธุระ',
#   'ผจล. ชอ. วิ.',
#   'ผู้ช่วยเจ้าอาวาสพระอารามหลวง ชั้นเอก ฝ่ายวิปัสสนาธุระ',
#   'รจล. ชท. วิ.',
#   'รองเจ้าอาวาสพระอารามหลวง ชั้นโท ฝ่ายวิปัสสนาธุระ',
#   'จล. ชต. วิ.',
#   'เจ้าอาวาสพระอารามหลวง ชั้นตรี ฝ่ายวิปัสสนาธุระ',
#   'พระราชาคณะชั้นสามัญ',
#   'สป.',
#   'พระราชาคณะชั้นสามัญเปรียญ',
#   'สป. วิ.',
#   'พระราชาคณะชั้นสามัญเปรียญ ฝ่ายวิปัสสนาธุระ',
#   'สย.',
#   'พระราคณะชั้นสามัญยก',
#   'สย. วิ.',
#   'พระราชาคณะชั้นสามัญ ฝ่ายวิปัสสนาธุระ',
#   'ทสป.',
#   'พระราชาคณะชั้นสามัญ เทียบเปรียญ',
#   'พระ',
#   'ขุน',
#   'หมื่น',
#   'หลวง',
#   'พระยา',
#   'เจ้าพระยา',
#   'สมเด็จเจ้าพระยา',
#   'กรมพระยา',
#   'สมเด็จกรมพระยา',
#   'พระครูสัญญาบัตร',
#   'พระครูสัญญาบัตร วัดราษฎร์',
#   'พระครูสัญญาบัตร พระอารามหลวง',
#   'พระครูสัญญาบัตรเจ้าคณะตำบล',
#   'พระครูสัญญาบัตรเจ้าคณะอำเภอ',
#   'พระครูสัญญาบัตรเจ้าคณะจังหวัด',
#   'นาย',
#   'นางสาว',
#   'น.ส.',
#   'นาง',
#   'เด็กชาย',
#   'ด.ช.',
#   'เด็กหญิง',
#   'ด.ญ.',
#   'ท่าน',
#   'ชื่อ',
#   'คุณ',
#   'คุณหญิง',
#   'คุณนาย',
#   'นายแพทย์',
#   'แพทย์หญิง',
#   'ทันตแพทย์',
#   'ทันตแพทย์หญิง',
#   'สัตวแพทย์',
#   'นายสัตวแพทย์',
#   'สัตวแพทย์หญิง',
#   'ศาสตราจารย์',
#   'ศ.',
#   'ศาสตราจารย์ ดอกเตอร์',
#   'ศ. ดร.',
#   'รองศาสตราจารย์',
#   'รศ.',
#   'รองศาสตราจารย์ ดอกเตอร์',
#   'รศ. ดร.',
#   'ผู้ช่วยศาสตรจารย์',
#   'ผศ.',
#   'ผู้ช่วยศาสตราจารย์ ดอกเตอร์',
#   'ผศ. ดร.',
#   'ดอกเตอร์',
#   'ดร.',
#   'อาจารย์',
#   'อ.',
#   'อาจารย์ ดอกเตอร์',
#   'อ. ดร.',
#   'ฯพณฯ',
#   'เสธ.',
#   'บิ๊ก',
#   'เสี่ย',
#   'ผู้อำนวยการ',
#   'รองผู้อำนวยการ',
#   'ผู้ช่วยผู้อำนวยการ',
#   'ผอ.',
#   'ผช.',
#   'ผู้กำกับ',
#   'ผกก.',
#   'รัฐมนตรี',
#   'รมต.',
#   'นายก',
#   '']}

# %%
def individual_preprocess( raw_data , split_sentence , count ,remove = [] , use_dictionary = False ):
    pre_data_frame = { "Sentence" : [] , "Word" : [] , "Tag" : [] }
    for word in raw_data:
        have = False
        if use_dictionary:
            have , tag = check_dictionary( word )
            
        if word in remove :
            None
        elif have :
            pre_data_frame["Sentence"].append( "Sentence: " + str(count) )
            pre_data_frame["Word"].append( word )
            pre_data_frame["Tag"].append( tag )
        elif word in split_sentence :
            count += 1
        else: 
            check = word.find('(')
            if check > 0:
                pre_data_frame["Sentence"].append( "Sentence: " + str(count) )
                pre_data_frame["Word"].append( word[ 0 : word.find('(')] )
                pre_data_frame["Tag"].append( word[ word.find('(') + 1 : word.find(')')] )
            else:
                pre_data_frame["Sentence"].append( "Sentence: " + str(count) )
                pre_data_frame["Word"].append( word )
                pre_data_frame["Tag"].append( "O" )
    return pre_data_frame , count

# %%
import pandas as pd
def preprocess( directory , list_file , count = 1 , individual = False , use_dictionary = False ):
    data_frame = pd.DataFrame( { "Sentence" : [] , "Word" : [] , "Tag" : [] } )
    if( individual ):
        word = read_all_line( directory , list_file ).split('|')
        pre_data_frame , count = individual_preprocess( word ,
                                              ["\n"] ,
                                              count ,
                                              [ "" , '' , '\0'] ,
                                              use_dictionary )
        data_frame  = data_frame.append( pd.DataFrame( pre_data_frame ), ignore_index=True )
    else:
        for file in list_file :
            word = read_all_line( directory , file ).split('|')
            pre_data_frame , count = individual_preprocess( word ,
                                              ["\n"] ,
                                              count ,
                                              [ "" , '' , '\0']  ,
                                              use_dictionary )
            data_frame  = data_frame.append( pd.DataFrame( pre_data_frame ), ignore_index=True )
    return data_frame

# %%
#directory of corpus
corpus_directory = "test_in_class"
corpus_files = ("Politic9.txt" , "Allcolumn.txt" , "98JUL5_1.txt" ,
                "98JUL5_2.txt" , "bkknews1.txt" , "Result1.txt" ,
                "Result2(corpus-1).txt" , "Result3(corpus-2).txt" ,
                "result4.txt" , "Result_c_2_1.txt", "Result_c_2_2.txt" )
corpus_test = ( "POL1108.CUT" , "POL1805.CUT" , "POL1812.CUT" ,  
                "POL1819.CUT" , "POL2008.CUT" , "POL2017.CUT" ,
                "POL1109.CUT" , "POL1806.CUT" , "POL1813.CUT" , 
                "POL2001.CUT" , "POL2009.CUT" , "POL2018.CUT" ,
                "POL1111.CUT" , "POL1807.CUT" , "POL1814.CUT" , 
                "POL2002.CUT" , "POL2010.CUT" , "POL2019.CUT" ,
                "POL1112.CUT" , "POL1808.CUT" , "POL1815.CUT" ,
                "POL2004.CUT" , "POL2011.CUT" , "POL2020.CUT" ,
                "POL1113.CUT" , "POL1809.CUT" , "POL1816.CUT" ,
                "POL2005.CUT" , "POL2012.CUT" , "POL1803.CUT" ,
                "POL1810.CUT" , "POL1817.CUT" , "POL2006.CUT" ,
                "POL2014.CUT" , "POL1804.CUT" , "POL1811.CUT" ,
                "POL1818.CUT" , "POL2007.CUT" , "POL2015.CUT" )
all_corpus = corpus_files + corpus_test
individual = False

# %%
data_frame = preprocess( corpus_directory + "/train_data" , 
                        corpus_files, 1 , False , True )
data_frame
number_words = len( set( list( data_frame["Word"].values ) ) )
number_tags = len( list( set( data_frame["Tag"].values ) ) )
print( "Have type of tag is " + str( number_tags ) + 
        " tags from " + str(number_words) + " words")
# print(set( list( data_frame["Tag"].values )))
# Out:
# Have type of tag is 15 tags from 9293 words

# %%
data_frame
# Out:
#               Sentence        Word        Tag
# 0          Sentence: 1           "          O
# 1          Sentence: 1  พลอากาศเอก  per_front
# 2          Sentence: 1      ทักษิณ        per
# 3          Sentence: 1           "          O
# 4          Sentence: 1                      O
# ...                ...         ...        ...
# 103379  Sentence: 5825        ทะเล    org_end
# 103380  Sentence: 5825                      O
# 103381  Sentence: 5825     จังหวัด          O
# 103382  Sentence: 5825      ภูเก็ต        loc
# 103383  Sentence: 5825                      O
#
# [103384 rows x 3 columns]

# %% [markdown]
# Follow https://towardsdatascience.com/named-entity-recognition-and-classification-with-scikit-learn-f05372f07ba2

# %%
data_frame['Sentence'].nunique(), data_frame.Word.nunique(), data_frame.Tag.nunique()
# Out:
# (5825, 9293, 15)

# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
data_frame = data_frame.fillna(method='ffill')
print( "Number of sentence is {:d}".format(data_frame['Sentence'].nunique()) )
print( "Number of word is {:d}".format( data_frame.Word.nunique() ) )
print( "Number of tag is {:d}".format( data_frame.Tag.nunique() ) )
# Out:
# Number of sentence is 5825
# Number of word is 9293
# Number of tag is 15

# %%
data_frame.groupby('Tag').size().reset_index(name='counts')
# Out:
#           Tag  counts
# 0                  33
# 1           O   85395
# 2         loc    2989
# 3    loc_cont      91
# 4     loc_end     183
# 5   loc_start     183
# 6         org    3195
# 7    org_cont    2470
# 8     org_end    1529
# 9   org_start    1553
# 10        per     830
# 11   per_cont    1306
# 12    per_end    1196
# 13  per_front    1235
# 14  per_start    1196

# %%
data_train = data_frame.drop('Tag', axis=1)
#vector_handle = DictVectorizer(sparse=False)
#data_train = vector_handle.fit_transform( data_train.to_dict('records') )
#value_train = data_frame.Tag.values

# %% [raw]
# # We want to remove label O because is common label don't have benefit to calculate about that

# %% [raw]
# Now we have linear model Perceptron next we have to prepare data for test

# %%
test_frame = preprocess( corpus_directory + "/test_tag" , corpus_test , 1 , individual )
#data_test = test_frame.drop('Tag', axis=1)
#vector_handle = DictVectorizer(sparse=False)
#data_test = vector_handle.fit_transform( data_test.to_dict('records') )
#value_test = test_frame.Tag.values

# %% [raw]
# Next I will test model but we have problem about shape of test and train we must to have same shape of matrix to do machine learning

# %%
data_frame.shape[0] , test_frame.shape[0]
# Out:
# (103384, 16273)

# %%
all_frame = data_frame.append( test_frame )
all_data = all_frame.drop('Tag', axis=1)
vector_handle = DictVectorizer(sparse=False)
all_data = vector_handle.fit_transform(all_data.to_dict('records'))
all_value = all_frame.Tag.values
size_of_test = test_frame.shape[0]
print( "Propotional of test is " + str( size_of_test ) )

classes = np.unique( all_value )
classes = classes.tolist()
new_classes = classes.copy()
new_classes.remove('O')
new_classes.remove('')
new_classes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-577137366265> in <module>
# ----> 1 all_frame = data_frame.append( test_frame )
#       2 all_data = all_frame.drop('Tag', axis=1)
#       3 vector_handle = DictVectorizer(sparse=False)
#       4 all_data = vector_handle.fit_transform(all_data.to_dict('records'))
#       5 all_value = all_frame.Tag.values
#
# NameError: name 'data_frame' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(all_data, 
        all_value, 
        test_size = size_of_test, 
        shuffle = False )

# %%
# Use Perceptron # the best from three model
per = Perceptron(verbose=10, n_jobs=-1, max_iter=5)
per.partial_fit(X_train, y_train, classes)

# %%
print(classification_report(y_pred=per.predict(X_test), 
                            y_true=y_test, labels=new_classes))

# %%
# Use Passive Aggressive Classifier # Not work
# pa =PassiveAggressiveClassifier()
# pa.partial_fit(X_train, y_train, classes)

# %%
#print(classification_report(y_pred=pa.predict(X_test),
                            #y_true=y_test, labels=new_classes))

# %%
# use naive bayes # NOT WORK
# nb = MultinomialNB(alpha=0.01)
# nb.partial_fit(X_train, y_train, classes)

# %%
#print(classification_report(y_pred=nb.predict(X_test), 
                            #y_true=y_test, labels = new_classes))
