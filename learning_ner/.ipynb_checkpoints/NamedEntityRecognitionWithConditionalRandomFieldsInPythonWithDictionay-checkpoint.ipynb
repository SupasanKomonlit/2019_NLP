# %% [markdown]
# This file will follow tutorial
# https://www.depends-on-the-definition.com/named-entity-recognition-conditional-random-fields-python/

# %%
import pandas as pd
import numpy as np

# %%
def read_all_line( directory , file ):
    file = open( directory + "/" + file , "r" , encoding="utf-8" )
    contents = file.read()
    file.close()
    return contents

# %%
dictionary_directory = "dictionary_directory"
dictionary_files = {
    "front_person" : ("clue front.txt" , "clue word person.txt" , "clue_royal.txt")
    ,"front_country" : ("คำนำหน้าชื่อประเทศ.txt")
    ,"front_org" : ("คำนำหน้าองค์กรจาก dict.txt")
    ,"location_name" : ("ชื่อกิ่งอำเภอ.txt" , "ชื่อคลอง.txt" , "ชื่อจังหวัด.txt" , "ชื่อตำบล.txt" , "ชื่อมลรัฐ.txt" , "ชื่อสถานที่.txt")
}

# %%
def prepare_dictionary( directory , file_dict ):
    dictionary = {}
    for key in file_dict.keys():
        dictionary[ key ] = []
        list_file = file_dict[ key ]
        if type( list_file ) == type( "test_string" ):
            dictionary[ key ] = read_all_line( directory , list_file ).split('\n')
        else:
            for file in list_file:
                dictionary[ key ] += read_all_line( directory , file ).split('\n')
    return dictionary

# If found in dict will return key other return NO
def search_in_dictionary( word , dictionary ):
    answer = "NO"
    for key in dictionary.keys():
        if word in dictionary[key]:
            answer = key
            break
    return answer

# %%
dictionary = prepare_dictionary( dictionary_directory , dictionary_files )
search_in_dictionary( "และ" , dictionary)
# Out:
# 'location_name'

# %%
def idividual_read_file( raw_data , split_sentence , count ,remove = [] ):
    pre_data_frame = { "Sentence #" : [] , "Word" : [] , "Tag" : [] , "Dictionary" : [] }
    for word in raw_data:
        if word in remove :
            None
        elif word in split_sentence :
            count += 1
        else: 
            check = word.find('(')
            if check > 0:
                temp_word = word[ 0 : word.find('(')]
                pre_data_frame["Sentence #"].append( "Sentence: " + str(count) )
                pre_data_frame["Word"].append( temp_word )
                pre_data_frame["Tag"].append( word[ word.find('(') + 1 : word.find(')')] )
                pre_data_frame["Dictionary"].append( search_in_dictionary( temp_word , dictionary ) )
            else:
                pre_data_frame["Sentence #"].append( "Sentence: " + str(count) )
                pre_data_frame["Word"].append( word )
                pre_data_frame["Tag"].append( "O" )
                pre_data_frame["Dictionary"].append( search_in_dictionary( word , dictionary ) )
    return pre_data_frame , count

def read_file( directory , list_file , count = 1 , individual = False ):
    data_frame = pd.DataFrame( { "Sentence #" : [] , "Word" : [] , "Tag" : [] , "Dictionary" : []} )
    if( individual ):
        word = read_all_line( directory , list_file ).split('|')
        pre_data_frame , count = idividual_read_file( word , # raw_data
                                              ["\n"] , # word show split sentence
                                              count , # order of sentence
                                              [ " " , '' , '\0'] ) # word to delete or prevent
        data_frame  = data_frame.append( pd.DataFrame( pre_data_frame ), ignore_index=True )
    else:
        for file in list_file :
            word = read_all_line( directory , file ).split('|')
            pre_data_frame , count = idividual_read_file( word ,
                                              ["\n"] ,
                                              count ,
                                              [ " " , '' , '\0'] )
            data_frame  = data_frame.append( pd.DataFrame( pre_data_frame ), ignore_index=True )
    return data_frame
def num_of_sentence( sentence ):
    words = sentence.split( " ")
    return int( words[1] )

# %%
# Variable for collect name file and access file
train_directory = "corpus_directory"
train_files = ("Politic9.txt" , "Allcolumn.txt" , "98JUL5_1.txt" ,
                "98JUL5_2.txt" , "bkknews1.txt" , "Result1.txt" ,
                "Result2(corpus-1).txt" , "Result3(corpus-2).txt" )
test_directory = "corpus_directory"
test_files = ("result4.txt" , "Result_c_2_1.txt", "Result_c_2_2.txt" )

# %% [raw]
# ข้างบนทั้งหมด คือการที่เราจะอ่าน text data แล้วได้ข้อมูลออกมาเป็น pandas.DataFrame

# %%
data = read_file( train_directory , train_files , 1 )
data.fillna( method="ffill")
data.tail( 10 )
# Out:
#            Sentence #       Word       Tag     Dictionary
# 52212  Sentence: 3762       แห่ง  org_cont             NO
# 52213  Sentence: 3762       ชาติ   org_end             NO
# 52214  Sentence: 3762       หรือ         O             NO
# 52215  Sentence: 3762     ป.ป.ช.       org             NO
# 52216  Sentence: 3762       ต้อง         O             NO
# 52217  Sentence: 3762     ประกาศ         O             NO
# 52218  Sentence: 3762  หลักเกณฑ์         O             NO
# 52219  Sentence: 3762        และ         O  location_name
# 52220  Sentence: 3762      จำนวน         O             NO
# 52221  Sentence: 3762  ทรัพย์สิน         O             NO

# %% [raw]
# เนื่องจาก tag หลากหลายมาก ส่วนเริ่มต้น ส่วนต่อ และส่วนจบ จึงจะจัดการให้เหลือเพียงส่วนเดียว

# %%
def merge_all_tag( data ):
    for run in range(  0 , data.shape[0] ):
        if data.Tag[run] in ( '' ):
            data.Tag[run] = 'O'
        elif data.Tag[run] in ('loc_cont','loc_end','loc_start'):
            data.Tag[run] = 'loc'
        elif data.Tag[run] in ('org_cont','org_end','org_start'):
            data.Tag[run] = 'org'
        elif data.Tag[run] in ('per_cont','per_end','per_start'):
            data.Tag[run] = 'per'
        else:
            None

# number is current index
# target is -1 -2 +1 +2 what do you want to file
def helper_get_tag( data , number , target , limit ):
    if( number + target == limit ):
        return 'O'
    elif( data["Sentence #"][ number+target ] != data["Sentence #"][ number ] ):
        return 'O'
    else:
        return data.Tag[number + target ]
            
def split_all_tag( data ):
    limit_run = data.shape[0]
    for run in range( 0 , limit_run ):
        if data.Tag[ run ] == "loc" :
            if( helper_get_tag( data , run , -1, limit_run  ) in ( "loc_start" , "loc_cont" ) ):
                if( helper_get_tag( data , run , +1 , limit_run ) == "loc" ):
                    data.Tag[ run ] = "loc_cont"
                else:
                    data.Tag[ run ] = "loc_end"
            elif( helper_get_tag( data , run , +1 , limit_run ) == "loc" ):
                data.Tag[ run ] = "loc_start"
        elif data.Tag[ run ] == "org" :
            if( helper_get_tag( data , run , -1 , limit_run ) in ( "org_start" , "org_cont" ) ):
                if( helper_get_tag( data , run , +1 , limit_run ) == "org" ):
                    data.Tag[ run ] = "org_cont"
                else:
                    data.Tag[ run ] = "org_end"
            elif( helper_get_tag( data , run , +1 , limit_run ) == "org" ):
                data.Tag[ run ] = "org_start"
        elif data.Tag[ run ] == "per" :
            if( helper_get_tag( data , run , -1 , limit_run ) in ( "per_start" , "per_cont" ) ):
                if( helper_get_tag( data , run , +1, limit_run ) == "per" ):
                    data.Tag[ run ] = "per_cont"
                else:
                    data.Tag[ run ] = "per_end"
            elif( helper_get_tag( data , run , +1 , limit_run ) == "per" ):
                data.Tag[ run ] = "per_start"
            else:
                None
        else:
            None

# %%
merge_all_tag( data )
words = list( set(data["Word"].values ) )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-1825b67291c3> in <module>
# ----> 1 data.Tag.Values
#       2 merge_all_tag( data )
#       3 words = list( set(data["Word"].values ) )
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'Values'

# %%
n_words = len( words )
n_sentence = num_of_sentence( data["Sentence #"][ data.shape[0]-1 ] )
print( "You have number of words is {} from {} sentences".format( n_words , n_sentence ))
# Out:
# You have number of words is 6527 from 3762 sentences

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 0
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, t, d) for w, t, d in zip( s["Word"].values.tolist(),
                                                            s["Tag"].values.tolist(),
                                                            s["Dictionary"].values.tolist() 
                                                          )]
        self.grouped = self.grouped_sentence()
        self.sentences = [s for s in self.grouped]
    
    def grouped_sentence( self ):
        save_sentence = 0
        major_index = 0
        temp_grouped = []
        for run in range( 0 , self.data.shape[0] ):
            temp_sentence = num_of_sentence( self.data["Sentence #"][ run ] )
            if save_sentence != temp_sentence :
                major_index = temp_sentence - 1
                save_sentence = temp_sentence
                temp_grouped.append( [] )
            temp_grouped[ major_index ].append( (self.data["Word"][run], 
                                                 self.data["Tag"][run],
                                                 self.data["Dictionary"][run] ) )
        return temp_grouped
    
    def get_next(self):
        try:
            s = self.grouped[ self.n_sent ]
            self.n_sent += 1
            return s  
        except:
            self.empty = True
            return None, None

# %%
getter = SentenceGetter( data )

# %%
sent= getter.get_next()

# %%
print(sent)
# Out:
# [('"', 'O', 'NO'), ('พลอากาศเอก', 'O', 'front_person'), ('ทักษิณ', 'per', 'NO'), ('"', 'O', 'NO'), ('ขอ', 'O', 'NO'), ('โอกาส', 'O', 'NO'), ('ให้', 'O', 'NO'), ('"', 'O', 'NO'), ('พล.ต.ท.', 'O', 'front_person'), ('เสรี', 'per', 'NO'), ('"', 'O', 'NO')]

# %% [markdown]
# ข้างบนนั้นจะดึงออกมาทีละประโยค โดยที่จะดึงคำออกมาพร้อมกับ tag นั้นเอง
# ดังนั้นต่อมาเราจะดึงออกทั้งหมด ทุกประโยคเลย

# %%
sentences = getter.sentences

# %%
def word2features(sent, i):
    word = sent[i][0]
    dict_type = sent[i][2]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'dictionary' : dict_type
    }
    if i > 0:
        word1 = sent[i-1][0]
        dict_type1 = sent[i-1][2]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:dictionay' : dict_type1
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        dict_type1 = sent[i+1][2]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '-1:dictionay' : dict_type1
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, label, dict_type in sent]

def sent2tokens(sent):
    return [token for token, label, dict_type in sent]

def sent2dict_type( sent ):
    return [dict_type for token, label, dict_type in sent]

# %% [markdown]
# ข้างบนเป็นการจัดรูปแบบ feature ของคำเฉยๆ ถ้าอยากรู้จะต้องอ่านเนื้อหาเกี่ยวกับ CRF เพิ่มเติมว่ามีแนวคิดอย่างไร คาดว่าจุดนี้อาจทำให้สามารถคำนวณโดยเอา Dict มาใช้ได้
# https://medium.com/ml2vec/overview-of-conditional-random-fields-68a2a20fa541

# %%
from sklearn_crfsuite import CRF

crf = CRF(algorithm='lbfgs',
          c1=0.1,
          c2=0.1,
          max_iterations=100,
          all_possible_transitions=False)

# %%
# ref for first module https://scikit-learn.org/stable/modules/cross_validation.html
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from sklearn_crfsuite.metrics import flat_classification_report

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

# %%
pred = cross_val_predict(estimator=crf, X=X, y=y, cv=5)

# %%
report = flat_classification_report(y_pred=pred, y_true=y)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            O       0.96      0.99      0.97     42210
#          loc       0.93      0.79      0.85      2117
#          org       0.85      0.69      0.76      5217
#          per       0.89      0.84      0.86      2678
#
#     accuracy                           0.94     52222
#    macro avg       0.91      0.83      0.86     52222
# weighted avg       0.94      0.94      0.94     52222

# %%
crf.fit(X, y)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=False,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
#import eli5

# %%
#eli5.show_weights(crf, top=30)

# %%
# reference https://machinelearningmastery.com/save-load-machine-learning-models-python-scikit-learn/
import pickle
model_directory = "model_directory"
model_name = "CRF_dictionary.sav"
model_file = model_directory + "/" + model_name

# %%
pickle.dump( crf , open( model_file , 'wb') )

# %%
load_model = pickle.load( open( model_file , 'rb') )

# %%
load_model
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=False,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
data_test = read_file( test_directory , test_files , 1 )
data_test.fillna( method="ffill")
data_test.tail( 10 )
# Out:
#            Sentence #      Word        Tag     Dictionary
# 36372  Sentence: 2064       และ          O  location_name
# 36373  Sentence: 2064    สถาบัน          O      front_org
# 36374  Sentence: 2064     วิจัย  org_start             NO
# 36375  Sentence: 2064  ชีววิทยา   org_cont             NO
# 36376  Sentence: 2064             org_cont             NO
# 36377  Sentence: 2064       และ   org_cont  location_name
# 36378  Sentence: 2064     ประมง   org_cont             NO
# 36379  Sentence: 2064      ทะเล    org_end             NO
# 36380  Sentence: 2064   จังหวัด          O             NO
# 36381  Sentence: 2064    ภูเก็ต        loc  location_name

# %%
merge_all_tag( data_test )

# %%
getter_test = SentenceGetter( data_test )

# %%
getter_test.get_next()
# Out:
# [('มา', 'O', 'NO'),
#  ('พูด', 'O', 'NO'),
#  ('คุย', 'O', 'NO'),
#  ('กัน', 'O', 'NO'),
#  ('ถึง', 'O', 'NO'),
#  ('เรื่อง', 'O', 'NO'),
#  ('ของ', 'O', 'NO'),
#  ('กองทุน', 'O', 'front_org'),
#  ('สำรอง', 'O', 'NO'),
#  ('เลี้ยง', 'O', 'NO'),
#  ('ชีพ', 'O', 'NO'),
#  ('ว่า', 'O', 'NO'),
#  ('จะ', 'O', 'NO'),
#  ('มี', 'O', 'NO'),
#  ('รูปแบบ', 'O', 'NO'),
#  ('อย่างไร', 'O', 'NO')]

# %%
sentences_test = getter_test.sentences
sentences_test[1]
# Out:
# [('มี', 'O', 'NO'),
#  ('ประเด็น', 'O', 'NO'),
#  ('คำถาม', 'O', 'NO'),
#  ('ที่', 'O', 'NO'),
#  ('เกี่ยวข้อง', 'O', 'NO'),
#  ('กับ', 'O', 'NO'),
#  ('กองทุน', 'O', 'front_org'),
#  ('บำเหน็จ', 'org', 'NO'),
#  ('บำนาญ', 'org', 'NO'),
#  ('ข้าราชการ', 'org', 'NO'),
#  ('(', 'O', 'NO'),
#  ('กบข.', 'org', 'NO'),
#  (')', 'O', 'NO'),
#  ('อย่าง', 'O', 'NO'),
#  ('มากมาย', 'O', 'NO')]

# %%
test_set = [sent2features(s) for s in sentences_test]
test_label = [sent2labels(s) for s in sentences_test]

# %%
test_predict = load_model.predict( test_set )

# %%
report = flat_classification_report(y_pred=test_predict, y_true=test_label)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            O       0.96      0.99      0.97     29673
#          loc       0.92      0.69      0.79      1329
#          org       0.84      0.71      0.77      3530
#          per       0.91      0.81      0.86      1850
#
#     accuracy                           0.94     36382
#    macro avg       0.91      0.80      0.85     36382
# weighted avg       0.94      0.94      0.94     36382

# %%
data_test.head( 20 )
# Out:
#      Sentence #     Word Tag Dictionary
# 0   Sentence: 1       มา   O         NO
# 1   Sentence: 1      พูด   O         NO
# 2   Sentence: 1      คุย   O         NO
# 3   Sentence: 1      กัน   O         NO
# 4   Sentence: 1      ถึง   O         NO
# 5   Sentence: 1   เรื่อง   O         NO
# 6   Sentence: 1      ของ   O         NO
# 7   Sentence: 1   กองทุน   O  front_org
# 8   Sentence: 1    สำรอง   O         NO
# 9   Sentence: 1   เลี้ยง   O         NO
# 10  Sentence: 1      ชีพ   O         NO
# 11  Sentence: 1      ว่า   O         NO
# 12  Sentence: 1       จะ   O         NO
# 13  Sentence: 1       มี   O         NO
# 14  Sentence: 1   รูปแบบ   O         NO
# 15  Sentence: 1  อย่างไร   O         NO
# 16  Sentence: 2       มี   O         NO
# 17  Sentence: 2  ประเด็น   O         NO
# 18  Sentence: 2    คำถาม   O         NO
# 19  Sentence: 2      ที่   O         NO

# %%
def convert_list_to_data_frame( data_frame , data_list ):
    save_sentence = 0
    major_index_list = 0
    minor_index_list = 0
    for run in range( 0 , data_frame.shape[0] ):
        temp_sentence = num_of_sentence( data_frame["Sentence #"][ run ] )
        if save_sentence != temp_sentence :
            major_index_list = temp_sentence - 1
            save_sentence = temp_sentence
            minor_index_list = 0
        print( "access [{}][{}]".format( major_index_list , minor_index_list ))
        data_frame["Tag"][run] = data_list[ major_index_list][ minor_index_list ]
        minor_index_list += 1

# %%
convert_list_to_data_frame( data_test , test_predict )
# Out:
# access [0][0]
# access [0][1]
# access [0][2]
# access [0][3]
# access [0][4]
# access [0][5]
# access [0][6]
# access [0][7]
# access [0][8]
# access [0][9]
# access [0][10]
# access [0][11]
# access [0][12]
# access [0][13]
# access [0][14]
# access [0][15]
# access [1][0]
# access [1][1]
# access [1][2]
# access [1][3]
# access [1][4]
# access [1][5]
# access [1][6]
# access [1][7]
# access [1][8]
# access [1][9]
# access [1][10]
# access [1][11]
# access [1][12]
# access [1][13]
# access [1][14]
# access [2][0]
# access [2][1]
# access [2][2]
# access [2][3]
# access [2][4]
# access [2][5]
# access [2][6]
# access [2][7]
# access [2][8]
# access [2][9]
# access [2][10]
# access [2][11]
# access [2][12]
# access [2][13]
# access [2][14]
# access [2][15]
# access [2][16]
# access [2][17]
# access [2][18]
# access [2][19]
# access [2][20]
# access [2][21]
# access [2][22]
# access [2][23]
# access [2][24]
# access [3][0]
# access [3][1]
# access [3][2]
# access [3][3]
# access [3][4]
# access [3][5]
# access [3][6]
# access [3][7]
# access [3][8]
# access [3][9]
# access [3][10]
# access [3][11]
# access [3][12]
# access [3][13]
# access [3][14]
# access [3][15]
# access [3][16]
# access [3][17]
# access [3][18]
# access [3][19]
# access [3][20]
# access [4][0]
# access [4][1]
# access [4][2]
# access [4][3]
# access [4][4]
# access [4][5]
# access [4][6]
# access [4][7]
# access [4][8]
# access [4][9]
# access [4][10]
# access [4][11]
# access [4][12]
# access [4][13]
# access [4][14]
# access [4][15]
# access [4][16]
# access [4][17]
# access [4][18]
# access [4][19]
# access [4][20]
# access [4][21]
# access [4][22]
# access [5][0]
# access [5][1]
# access [5][2]
# access [5][3]
# access [5][4]
# access [5][5]
# access [5][6]
# access [5][7]
# access [5][8]
# access [5][9]
# access [5][10]
# access [6][0]
# access [6][1]
# access [6][2]
# access [6][3]
# access [6][4]
# access [6][5]
# access [6][6]
# access [6][7]
# access [6][8]
# access [6][9]
# access [6][10]
# access [6][11]
# access [7][0]
# access [7][1]
# access [7][2]
# access [8][0]
# access [8][1]
# access [8][2]
# access [8][3]
# access [8][4]
# access [8][5]
# access [8][6]
# access [8][7]
# access [8][8]
# access [8][9]
# access [8][10]
# access [8][11]
# access [9][0]
# access [9][1]
# access [9][2]
# access [9][3]
# access [9][4]
# access [9][5]
# access [9][6]
# access [9][7]
# access [9][8]
# access [9][9]
# access [9][10]
# access [9][11]
# access [9][12]
# access [9][13]
# access [9][14]
# access [9][15]
# access [9][16]
# access [9][17]
# access [9][18]
# access [9][19]
# access [9][20]
# access [9][21]
# access [9][22]
# access [9][23]
# access [9][24]
# access [9][25]
# access [9][26]
# access [9][27]
# access [9][28]
# access [9][29]
# access [9][30]
# access [9][31]
# access [9][32]
# access [9][33]
# access [9][34]
# access [9][35]
# access [9][36]
# access [9][37]
# access [9][38]
# access [9][39]
# access [9][40]
# access [9][41]
# access [9][42]
# access [9][43]
# access [9][44]
# access [10][0]
# access [10][1]
# access [10][2]
# access [10][3]
# access [10][4]
# access [10][5]
# access [10][6]
# access [10][7]
# access [10][8]
# access [10][9]
# access [10][10]
# access [10][11]
# access [10][12]
# access [10][13]
# access [10][14]
# access [10][15]
# access [10][16]
# access [10][17]
# access [10][18]
# access [10][19]
# access [11][0]
# access [11][1]
# access [11][2]
# access [11][3]
# access [11][4]
# access [11][5]
# access [11][6]
# access [11][7]
# access [11][8]
# access [11][9]
# access [11][10]
# access [11][11]
# access [11][12]
# access [12][0]
# access [12][1]
# access [12][2]
# access [12][3]
# access [12][4]
# access [12][5]
# access [12][6]
# access [12][7]
# access [12][8]
# access [12][9]
# access [12][10]
# access [12][11]
# access [12][12]
# access [12][13]
# access [12][14]
# access [12][15]
# access [12][16]
# access [12][17]
# access [12][18]
# access [12][19]
# access [12][20]
# access [12][21]
# access [12][22]
# access [12][23]
# access [12][24]
# access [12][25]
# access [12][26]
# access [12][27]
# access [12][28]
# access [12][29]
# access [12][30]
# access [13][0]
# access [13][1]
# access [13][2]
# access [13][3]
# access [13][4]
# access [13][5]
# access [13][6]
# access [13][7]
# access [13][8]
# access [13][9]
# access [13][10]
# access [13][11]
# access [13][12]
# access [13][13]
# access [13][14]
# access [13][15]
# access [13][16]
# access [13][17]
# access [13][18]
# access [13][19]
# access [13][20]
# access [13][21]
# access [13][22]
# access [13][23]
# access [13][24]
# access [13][25]
# access [13][26]
# access [13][27]
# access [13][28]
# access [13][29]
# access [13][30]
# access [13][31]
# access [13][32]
# access [13][33]
# access [13][34]
# access [14][0]
# access [14][1]
# access [14][2]
# access [14][3]
# access [14][4]
# access [14][5]
# access [14][6]
# access [14][7]
# access [14][8]
# access [14][9]
# access [14][10]
# access [14][11]
# access [14][12]
# access [14][13]
# access [14][14]
# access [14][15]
# access [14][16]
# access [15][0]
# access [15][1]
# access [15][2]
# access [15][3]
# access [15][4]
# access [15][5]
# access [15][6]
# access [15][7]
# access [15][8]
# access [15][9]
# access [15][10]
# access [15][11]
# access [15][12]
# access [15][13]
# access [15][14]
# access [15][15]
# access [15][16]
# access [15][17]
# access [15][18]
# access [15][19]
# access [15][20]
# access [15][21]
# access [16][0]
# access [16][1]
# access [16][2]
# access [16][3]
# access [16][4]
# access [16][5]
# access [16][6]
# access [16][7]
# access [16][8]
# access [16][9]
# access [16][10]
# access [16][11]
# access [16][12]
# access [16][13]
# access [16][14]
# access [16][15]
# access [16][16]
# access [16][17]
# access [16][18]
# access [16][19]
# access [16][20]
# access [16][21]
# access [16][22]
# access [16][23]
# access [16][24]
# access [16][25]
# access [16][26]
# access [16][27]
# access [16][28]
# access [16][29]
# access [16][30]
# access [16][31]
# access [16][32]
# access [16][33]
# access [16][34]
# access [16][35]
# access [16][36]
# access [16][37]
# access [16][38]
# access [16][39]
# access [16][40]
# access [16][41]
# access [16][42]
# access [16][43]
# access [16][44]
# access [17][0]
# access [17][1]
# access [17][2]
# access [17][3]
# access [17][4]
# access [17][5]
# access [17][6]
# access [17][7]
# access [17][8]
# access [17][9]
# access [17][10]
# access [17][11]
# access [18][0]
# access [18][1]
# access [18][2]
# access [18][3]
# access [18][4]
# access [18][5]
# access [18][6]
# access [18][7]
# access [18][8]
# access [18][9]
# access [18][10]
# access [18][11]
# access [19][0]
# access [19][1]
# access [19][2]
# access [19][3]
# access [19][4]
# access [20][0]
# access [20][1]
# access [20][2]
# access [20][3]
# access [20][4]
# access [20][5]
# access [20][6]
# access [20][7]
# access [20][8]
# access [20][9]
# access [20][10]
# access [20][11]
# access [20][12]
# access [20][13]
# access [20][14]
# access [20][15]
# access [20][16]
# access [20][17]
# access [20][18]
# access [20][19]
# access [20][20]
# access [21][0]
# access [21][1]
# access [21][2]
# access [21][3]
# access [21][4]
# access [21][5]
# access [21][6]
# access [21][7]
# access [21][8]
# access [21][9]
# access [21][10]
# access [21][11]
# access [21][12]
# access [21][13]
# access [21][14]
# access [21][15]
# access [21][16]
# access [22][0]
# access [22][1]
# access [22][2]
# access [22][3]
# access [22][4]
# access [22][5]
# access [22][6]
# access [22][7]
# access [22][8]
# access [22][9]
# access [22][10]
# access [22][11]
# access [22][12]
# access [22][13]
# access [22][14]
# access [22][15]
# access [22][16]
# access [22][17]
# access [22][18]
# access [22][19]
# access [22][20]
# access [22][21]
# access [22][22]
# access [22][23]
# access [22][24]
# access [22][25]
# access [22][26]
# access [22][27]
# access [22][28]
# access [22][29]
# access [22][30]
# access [22][31]
# access [22][32]
# access [23][0]
# access [23][1]
# access [23][2]
# access [23][3]
# access [23][4]
# access [23][5]
# access [23][6]
# access [23][7]
# access [23][8]
# access [23][9]
# access [23][10]
# access [23][11]
# access [23][12]
# access [24][0]
# access [24][1]
# access [24][2]
# access [24][3]
# access [24][4]
# access [24][5]
# access [24][6]
# access [24][7]
# access [24][8]
# access [24][9]
# access [24][10]
# access [25][0]
# access [25][1]
# access [25][2]
# access [25][3]
# access [25][4]
# access [25][5]
# access [25][6]
# access [25][7]
# access [25][8]
# access [25][9]
# access [25][10]
# access [25][11]
# access [25][12]
# access [25][13]
# access [25][14]
# access [25][15]
# access [25][16]
# access [25][17]
# access [26][0]
# access [26][1]
# access [26][2]
# access [26][3]
# access [26][4]
# access [26][5]
# access [26][6]
# access [26][7]
# access [26][8]
# access [26][9]
# access [26][10]
# access [27][0]
# access [27][1]
# access [27][2]
# access [27][3]
# access [27][4]
# access [27][5]
# access [27][6]
# access [27][7]
# access [27][8]
# access [27][9]
# access [27][10]
# access [27][11]
# access [27][12]
# access [27][13]
# access [27][14]
# access [27][15]
# access [27][16]
# access [28][0]
# access [28][1]
# access [28][2]
# access [28][3]
# access [28][4]
# access [28][5]
# access [28][6]
# access [28][7]
# access [28][8]
# access [28][9]
# access [28][10]
# access [28][11]
# access [28][12]
# access [28][13]
# access [28][14]
# access [28][15]
# access [28][16]
# access [28][17]
# access [28][18]
# access [28][19]
# access [28][20]
# access [28][21]
# access [28][22]
# access [29][0]
# access [29][1]
# access [29][2]
# access [29][3]
# access [29][4]
# access [29][5]
# access [29][6]
# access [29][7]
# access [29][8]
# access [29][9]
# access [29][10]
# access [30][0]
# access [30][1]
# access [30][2]
# access [30][3]
# access [30][4]
# access [30][5]
# access [30][6]
# access [30][7]
# access [30][8]
# access [30][9]
# access [30][10]
# access [30][11]
# access [30][12]
# access [30][13]
# access [30][14]
# access [30][15]
# access [30][16]
# access [30][17]
# access [30][18]
# access [30][19]
# access [31][0]
# access [31][1]
# access [31][2]
# access [31][3]
# access [31][4]
# access [31][5]
# access [31][6]
# access [31][7]
# access [31][8]
# access [31][9]
# access [31][10]
# access [31][11]
# access [31][12]
# access [31][13]
# access [31][14]
# access [31][15]
# access [31][16]
# access [31][17]
# access [31][18]
# access [31][19]
# access [31][20]
# access [31][21]
# access [31][22]
# access [31][23]
# access [31][24]
# access [31][25]
# access [31][26]
# access [31][27]
# access [31][28]
# access [31][29]
# access [32][0]
# access [32][1]
# access [32][2]
# access [32][3]
# access [32][4]
# access [32][5]
# access [32][6]
# access [32][7]
# access [32][8]
# access [32][9]
# access [32][10]
# access [32][11]
# access [32][12]
# access [32][13]
# access [32][14]
# access [32][15]
# access [32][16]
# access [32][17]
# access [32][18]
# access [32][19]
# access [32][20]
# access [32][21]
# access [32][22]
# access [32][23]
# access [32][24]
# access [32][25]
# access [32][26]
# access [32][27]
# access [33][0]
# access [33][1]
# access [33][2]
# access [33][3]
# access [33][4]
# access [33][5]
# access [33][6]
# access [33][7]
# access [33][8]
# access [33][9]
# access [33][10]
# access [33][11]
# access [33][12]
# access [33][13]
# access [33][14]
# access [33][15]
# access [33][16]
# access [34][0]
# access [34][1]
# access [34][2]
# access [34][3]
# access [34][4]
# access [34][5]
# access [34][6]
# access [34][7]
# access [34][8]
# access [34][9]
# access [34][10]
# access [34][11]
# access [34][12]
# access [34][13]
# access [34][14]
# access [34][15]
# access [34][16]
# access [34][17]
# access [34][18]
# access [35][0]
# access [35][1]
# access [35][2]
# access [35][3]
# access [35][4]
# access [35][5]
# access [35][6]
# access [35][7]
# access [35][8]
# access [35][9]
# access [35][10]
# access [35][11]
# access [35][12]
# access [35][13]
# access [35][14]
# access [35][15]
# access [35][16]
# access [35][17]
# access [35][18]
# access [35][19]
# access [35][20]
# access [35][21]
# access [35][22]
# access [35][23]
# access [35][24]
# access [35][25]
# access [36][0]
# access [36][1]
# access [36][2]
# access [36][3]
# access [36][4]
# access [36][5]
# access [36][6]
# access [36][7]
# access [36][8]
# access [36][9]
# access [36][10]
# access [37][0]
# access [37][1]
# access [37][2]
# access [37][3]
# access [37][4]
# access [37][5]
# access [37][6]
# access [37][7]
# access [37][8]
# access [37][9]
# access [37][10]
# access [37][11]
# access [37][12]
# access [37][13]
# access [37][14]
# access [37][15]
# access [37][16]
# access [37][17]
# access [37][18]
# access [37][19]
# access [37][20]
# access [37][21]
# access [37][22]
# access [37][23]
# access [38][0]
# access [38][1]
# access [38][2]
# access [38][3]
# access [38][4]
# access [38][5]
# access [38][6]
# access [38][7]
# access [39][0]
# access [39][1]
# access [39][2]
# access [39][3]
# access [39][4]
# access [39][5]
# access [39][6]
# access [39][7]
# access [39][8]
# access [39][9]
# access [39][10]
# access [39][11]
# access [39][12]
# access [40][0]
# access [40][1]
# access [40][2]
# access [40][3]
# access [40][4]
# access [40][5]
# access [40][6]
# access [40][7]
# access [40][8]
# access [40][9]
# access [40][10]
# access [40][11]
# access [40][12]
# access [40][13]
# access [40][14]
# access [40][15]
# access [40][16]
# access [40][17]
# access [40][18]
# access [40][19]
# access [40][20]
# access [40][21]
# access [40][22]
# access [40][23]
# access [40][24]
# access [40][25]
# access [40][26]
# access [40][27]
# access [40][28]
# access [40][29]
# access [40][30]
# access [40][31]
# access [40][32]
# access [40][33]
# access [40][34]
# access [40][35]
# access [40][36]
# access [40][37]
# access [40][38]
# access [40][39]
# access [40][40]
# access [40][41]
# access [40][42]
# access [40][43]
# access [40][44]
# access [40][45]
# access [40][46]
# access [40][47]
# access [40][48]
# access [40][49]
# access [40][50]
# access [40][51]
# access [40][52]
# access [40][53]
# access [40][54]
# access [40][55]
# access [41][0]
# access [41][1]
# access [41][2]
# access [41][3]
# access [41][4]
# access [41][5]
# access [41][6]
# access [41][7]
# access [41][8]
# access [41][9]
# access [41][10]
# access [41][11]
# access [41][12]
# access [41][13]
# access [41][14]
# access [41][15]
# access [41][16]
# access [41][17]
# access [41][18]
# access [41][19]
# access [41][20]
# access [42][0]
# access [42][1]
# access [42][2]
# access [42][3]
# access [42][4]
# access [42][5]
# access [42][6]
# access [42][7]
# access [42][8]
# access [42][9]
# access [42][10]
# access [42][11]
# access [42][12]
# access [42][13]
# access [42][14]
# access [42][15]
# access [42][16]
# access [42][17]
# access [42][18]
# access [42][19]
# access [42][20]
# access [42][21]
# access [42][22]
# access [42][23]
# access [42][24]
# access [42][25]
# access [42][26]
# access [42][27]
# access [42][28]
# access [42][29]
# access [42][30]
# access [43][0]
# access [43][1]
# access [43][2]
# access [43][3]
# access [43][4]
# access [43][5]
# access [43][6]
# access [43][7]
# access [43][8]
# access [43][9]
# access [43][10]
# access [43][11]
# access [43][12]
# access [43][13]
# access [43][14]
# access [43][15]
# access [43][16]
# access [43][17]
# access [43][18]
# access [43][19]
# access [43][20]
# access [43][21]
# access [43][22]
# access [43][23]
# access [43][24]
# access [43][25]
# access [43][26]
# access [43][27]
# access [43][28]
# access [43][29]
# access [43][30]
# access [43][31]
# access [43][32]
# access [43][33]
# access [43][34]
# access [43][35]
# access [43][36]
# access [43][37]
# access [43][38]
# access [43][39]
# access [43][40]
# access [43][41]
# access [43][42]
# access [43][43]
# access [43][44]
# access [43][45]
# access [43][46]
# access [43][47]
# access [43][48]
# access [43][49]
# access [44][0]
# access [44][1]
# access [44][2]
# access [44][3]
# access [44][4]
# access [44][5]
# access [44][6]
# access [44][7]
# access [44][8]
# access [44][9]
# access [44][10]
# access [44][11]
# access [44][12]
# access [44][13]
# access [44][14]
# access [44][15]
# access [44][16]
# access [44][17]
# access [44][18]
# access [44][19]
# access [44][20]
# access [44][21]
# access [44][22]
# access [44][23]
# access [44][24]
# access [44][25]
# access [44][26]
# access [44][27]
# access [44][28]
# access [44][29]
# access [44][30]
# access [44][31]
# access [45][0]
# access [45][1]
# access [45][2]
# access [45][3]
# access [45][4]
# access [45][5]
# access [45][6]
# access [45][7]
# access [45][8]
# access [45][9]
# access [45][10]
# access [45][11]
# access [45][12]
# access [45][13]
# access [45][14]
# access [45][15]
# access [45][16]
# access [45][17]
# access [45][18]
# access [45][19]
# access [45][20]
# access [45][21]
# access [45][22]
# access [45][23]
# access [45][24]
# access [45][25]
# access [45][26]
# access [45][27]
# access [45][28]
# access [45][29]
# access [45][30]
# access [45][31]
# access [45][32]
# access [45][33]
# access [45][34]
# access [45][35]
# access [45][36]
# access [45][37]
# access [45][38]
# access [45][39]
# access [45][40]
# access [45][41]
# access [45][42]
# access [45][43]
# access [45][44]
# access [45][45]
# access [45][46]
# access [45][47]
# access [45][48]
# access [45][49]
# access [45][50]
# access [45][51]
# access [45][52]
# access [45][53]
# access [45][54]
# access [45][55]
# access [46][0]
# access [46][1]
# access [46][2]
# access [46][3]
# access [46][4]
# access [46][5]
# access [46][6]
# access [46][7]
# access [46][8]
# access [46][9]
# access [46][10]
# access [46][11]
# access [46][12]
# access [46][13]
# access [46][14]
# access [46][15]
# access [46][16]
# access [46][17]
# access [46][18]
# access [46][19]
# access [46][20]
# access [46][21]
# access [46][22]
# access [46][23]
# access [46][24]
# access [46][25]
# access [46][26]
# access [46][27]
# access [46][28]
# access [46][29]
# access [46][30]
# access [46][31]
# access [47][0]
# access [47][1]
# access [47][2]
# access [47][3]
# access [47][4]
# access [47][5]
# access [47][6]
# access [47][7]
# access [47][8]
# access [47][9]
# access [47][10]
# access [47][11]
# access [47][12]
# access [47][13]
# access [47][14]
# access [47][15]
# access [47][16]
# access [47][17]
# access [47][18]
# access [47][19]
# access [47][20]
# access [47][21]
# access [47][22]
# access [47][23]
# access [47][24]
# access [47][25]
# access [47][26]
# access [47][27]
# access [47][28]
# access [47][29]
# access [47][30]
# access [47][31]
# access [47][32]
# access [47][33]
# access [47][34]
# access [47][35]
# access [47][36]
# access [47][37]
# access [47][38]
# access [47][39]
# access [47][40]
# access [47][41]
# access [47][42]
# access [47][43]
# access [47][44]
# access [47][45]
# access [47][46]
# access [47][47]
# access [47][48]
# access [47][49]
# access [47][50]
# access [47][51]
# access [47][52]
# access [47][53]
# access [47][54]
# access [47][55]
# access [47][56]
# access [47][57]
# access [47][58]
# access [47][59]
# access [47][60]
# access [48][0]
# access [48][1]
# access [48][2]
# access [48][3]
# access [48][4]
# access [48][5]
# access [48][6]
# access [48][7]
# access [48][8]
# access [48][9]
# access [48][10]
# access [49][0]
# access [49][1]
# access [49][2]
# access [49][3]
# access [49][4]
# access [49][5]
# access [49][6]
# access [49][7]
# access [49][8]
# access [49][9]
# access [49][10]
# access [49][11]
# access [49][12]
# access [49][13]
# access [49][14]
# access [49][15]
# access [49][16]
# access [49][17]
# access [49][18]
# access [49][19]
# access [49][20]
# access [49][21]
# access [49][22]
# access [49][23]
# access [49][24]
# access [49][25]
# access [49][26]
# access [50][0]
# access [50][1]
# access [50][2]
# access [50][3]
# access [50][4]
# access [50][5]
# access [50][6]
# access [50][7]
# access [50][8]
# access [50][9]
# access [50][10]
# access [50][11]
# access [50][12]
# access [50][13]
# access [50][14]
# access [50][15]
# access [50][16]
# access [50][17]
# access [50][18]
# access [50][19]
# access [50][20]
# access [50][21]
# access [50][22]
# access [50][23]
# access [50][24]
# access [50][25]
# access [50][26]
# access [50][27]
# access [50][28]
# access [50][29]
# access [50][30]
# access [50][31]
# access [50][32]
# access [51][0]
# access [51][1]
# access [51][2]
# access [51][3]
# access [51][4]
# access [51][5]
# access [51][6]
# access [51][7]
# access [51][8]
# access [51][9]
# access [51][10]
# access [51][11]
# access [51][12]
# access [51][13]
# access [51][14]
# access [51][15]
# access [51][16]
# access [51][17]
# access [51][18]
# access [51][19]
# access [51][20]
# access [51][21]
# access [51][22]
# access [51][23]
# access [51][24]
# access [51][25]
# access [51][26]
# access [51][27]
# access [51][28]
# access [51][29]
# access [51][30]
# access [51][31]
# access [51][32]
# access [51][33]
# access [51][34]
# access [51][35]
# access [51][36]
# access [51][37]
# access [51][38]
# access [51][39]
# access [51][40]
# access [51][41]
# access [51][42]
# access [52][0]
# access [52][1]
# access [52][2]
# access [52][3]
# access [52][4]
# access [52][5]
# access [52][6]
# access [52][7]
# access [52][8]
# access [52][9]
# access [52][10]
# access [52][11]
# access [52][12]
# access [52][13]
# access [52][14]
# access [52][15]
# access [52][16]
# access [52][17]
# access [52][18]
# access [53][0]
# access [53][1]
# access [53][2]
# access [53][3]
# access [53][4]
# access [53][5]
# access [53][6]
# access [53][7]
# access [53][8]
# access [53][9]
# access [53][10]
# access [53][11]
# access [53][12]
# access [53][13]
# access [53][14]
# access [53][15]
# access [53][16]
# access [53][17]
# access [53][18]
# access [53][19]
# access [53][20]
# access [53][21]
# access [53][22]
# access [53][23]
# access [53][24]
# access [53][25]
# access [53][26]
# access [53][27]
# access [53][28]
# access [53][29]
# access [53][30]
# access [53][31]
# access [53][32]
# access [53][33]
# access [53][34]
# access [53][35]
# access [53][36]
# access [53][37]
# access [53][38]
# access [53][39]
# access [54][0]
# access [54][1]
# access [54][2]
# access [54][3]
# access [54][4]
# access [54][5]
# access [54][6]
# access [54][7]
# access [54][8]
# access [54][9]
# access [54][10]
# access [54][11]
# access [54][12]
# access [54][13]
# access [54][14]
# access [54][15]
# access [54][16]
# access [54][17]
# access [54][18]
# access [54][19]
# access [54][20]
# access [54][21]
# access [54][22]
# access [54][23]
# access [54][24]
# access [54][25]
# access [54][26]
# access [54][27]
# access [54][28]
# access [54][29]
# access [54][30]
# access [54][31]
# access [54][32]
# access [54][33]
# access [54][34]
# access [54][35]
# access [54][36]
# access [54][37]
# access [54][38]
# access [54][39]
# access [54][40]
# access [54][41]
# access [54][42]
# access [54][43]
# access [54][44]
# access [54][45]
# access [54][46]
# access [54][47]
# access [54][48]
# access [54][49]
# access [54][50]
# access [54][51]
# access [54][52]
# access [54][53]
# access [54][54]
# access [54][55]
# access [55][0]
# access [55][1]
# access [55][2]
# access [55][3]
# access [55][4]
# access [55][5]
# access [55][6]
# access [55][7]
# access [55][8]
# access [55][9]
# access [55][10]
# access [55][11]
# access [55][12]
# access [55][13]
# access [55][14]
# access [55][15]
# access [55][16]
# access [55][17]
# access [55][18]
# access [55][19]
# access [55][20]
# access [55][21]
# access [55][22]
# access [55][23]
# access [55][24]
# access [55][25]
# access [55][26]
# access [55][27]
# access [55][28]
# access [55][29]
# access [55][30]
# access [55][31]
# access [55][32]
# access [55][33]
# access [55][34]
# access [55][35]
# access [55][36]
# access [55][37]
# access [55][38]
# access [56][0]
# access [56][1]
# access [56][2]
# access [56][3]
# access [56][4]
# access [56][5]
# access [56][6]
# access [56][7]
# access [56][8]
# access [56][9]
# access [56][10]
# access [56][11]
# access [56][12]
# access [56][13]
# access [56][14]
# access [56][15]
# access [56][16]
# access [57][0]
# access [57][1]
# access [57][2]
# access [57][3]
# access [57][4]
# access [57][5]
# access [57][6]
# access [57][7]
# access [57][8]
# access [57][9]
# access [57][10]
# access [57][11]
# access [57][12]
# access [57][13]
# access [57][14]
# access [57][15]
# access [57][16]
# access [57][17]
# access [58][0]
# access [58][1]
# access [58][2]
# access [58][3]
# access [58][4]
# access [58][5]
# access [58][6]
# access [58][7]
# access [58][8]
# access [58][9]
# access [58][10]
# access [58][11]
# access [58][12]
# access [58][13]
# access [58][14]
# access [58][15]
# access [58][16]
# access [58][17]
# access [58][18]
# access [58][19]
# access [58][20]
# access [58][21]
# access [58][22]
# access [58][23]
# access [58][24]
# access [58][25]
# access [58][26]
# access [58][27]
# access [58][28]
# access [58][29]
# access [58][30]
# access [58][31]
# access [58][32]
# access [58][33]
# access [58][34]
# access [58][35]
# access [58][36]
# access [58][37]
# access [58][38]
# access [58][39]
# access [58][40]
# access [58][41]
# access [58][42]
# access [58][43]
# access [58][44]
# access [58][45]
# access [58][46]
# access [58][47]
# access [58][48]
# access [58][49]
# access [58][50]
# access [58][51]
# access [58][52]
# access [58][53]
# access [58][54]
# access [58][55]
# access [58][56]
# access [58][57]
# access [59][0]
# access [59][1]
# access [59][2]
# access [59][3]
# access [59][4]
# access [59][5]
# access [59][6]
# access [59][7]
# access [59][8]
# access [59][9]
# access [59][10]
# access [60][0]
# access [60][1]
# access [60][2]
# access [60][3]
# access [60][4]
# access [60][5]
# access [60][6]
# access [60][7]
# access [60][8]
# access [60][9]
# access [60][10]
# access [60][11]
# access [60][12]
# access [61][0]
# access [61][1]
# access [61][2]
# access [61][3]
# access [61][4]
# access [61][5]
# access [61][6]
# access [61][7]
# access [61][8]
# access [61][9]
# access [61][10]
# access [61][11]
# access [61][12]
# access [61][13]
# access [61][14]
# access [61][15]
# access [61][16]
# access [61][17]
# access [61][18]
# access [61][19]
# access [61][20]
# access [61][21]
# access [61][22]
# access [61][23]
# access [61][24]
# access [61][25]
# access [61][26]
# access [61][27]
# access [61][28]
# access [61][29]
# access [61][30]
# access [61][31]
# access [61][32]
# access [61][33]
# access [61][34]
# access [61][35]
# access [61][36]
# access [61][37]
# access [61][38]
# access [61][39]
# access [61][40]
# access [61][41]
# access [62][0]
# access [62][1]
# access [62][2]
# access [62][3]
# access [62][4]
# access [62][5]
# access [62][6]
# access [62][7]
# access [62][8]
# access [62][9]
# access [62][10]
# access [62][11]
# access [62][12]
# access [62][13]
# access [62][14]
# access [62][15]
# access [62][16]
# access [63][0]
# access [63][1]
# access [63][2]
# access [63][3]
# access [63][4]
# access [63][5]
# access [63][6]
# access [63][7]
# access [63][8]
# access [63][9]
# access [63][10]
# access [63][11]
# access [63][12]
# access [63][13]
# access [63][14]
# access [63][15]
# access [63][16]
# access [63][17]
# access [63][18]
# access [63][19]
# access [63][20]
# access [63][21]
# access [63][22]
# access [63][23]
# access [63][24]
# access [64][0]
# access [64][1]
# access [64][2]
# access [64][3]
# access [64][4]
# access [64][5]
# access [64][6]
# access [64][7]
# access [64][8]
# access [64][9]
# access [64][10]
# access [64][11]
# access [64][12]
# access [64][13]
# access [64][14]
# access [64][15]
# access [65][0]
# access [65][1]
# access [65][2]
# access [65][3]
# access [65][4]
# access [65][5]
# access [65][6]
# access [65][7]
# access [65][8]
# access [65][9]
# access [65][10]
# access [65][11]
# access [65][12]
# access [65][13]
# access [65][14]
# access [65][15]
# access [65][16]
# access [65][17]
# access [65][18]
# access [65][19]
# access [65][20]
# access [65][21]
# access [65][22]
# access [65][23]
# access [65][24]
# access [65][25]
# access [65][26]
# access [65][27]
# access [65][28]
# access [65][29]
# access [66][0]
# access [66][1]
# access [66][2]
# access [66][3]
# access [66][4]
# access [66][5]
# access [66][6]
# access [66][7]
# access [66][8]
# access [66][9]
# access [66][10]
# access [66][11]
# access [66][12]
# access [66][13]
# access [66][14]
# access [66][15]
# access [66][16]
# access [66][17]
# access [66][18]
# access [66][19]
# access [66][20]
# access [66][21]
# access [66][22]
# access [66][23]
# access [66][24]
# access [66][25]
# access [66][26]
# access [66][27]
# access [66][28]
# access [66][29]
# access [66][30]
# access [66][31]
# access [66][32]
# access [66][33]
# access [66][34]
# access [66][35]
# access [66][36]
# access [66][37]
# access [66][38]
# access [66][39]
# access [66][40]
# access [66][41]
# access [67][0]
# access [67][1]
# access [67][2]
# access [67][3]
# access [67][4]
# access [67][5]
# access [67][6]
# access [67][7]
# access [67][8]
# access [67][9]
# access [67][10]
# access [67][11]
# access [67][12]
# access [67][13]
# access [67][14]
# access [67][15]
# access [67][16]
# access [67][17]
# access [67][18]
# access [67][19]
# access [67][20]
# access [67][21]
# access [67][22]
# access [67][23]
# access [67][24]
# access [67][25]
# access [67][26]
# access [67][27]
# access [67][28]
# access [67][29]
# access [67][30]
# access [67][31]
# access [67][32]
# access [67][33]
# access [67][34]
# access [67][35]
# access [67][36]
# access [67][37]
# access [67][38]
# access [67][39]
# access [67][40]
# access [68][0]
# access [68][1]
# access [68][2]
# access [68][3]
# access [68][4]
# access [68][5]
# access [68][6]
# access [68][7]
# access [68][8]
# access [68][9]
# access [68][10]
# access [68][11]
# access [68][12]
# access [68][13]
# access [68][14]
# access [68][15]
# access [68][16]
# access [68][17]
# access [68][18]
# access [68][19]
# access [68][20]
# access [68][21]
# access [68][22]
# access [68][23]
# access [68][24]
# access [68][25]
# access [68][26]
# access [68][27]
# access [68][28]
# access [68][29]
# access [68][30]
# access [68][31]
# access [68][32]
# access [68][33]
# access [69][0]
# access [69][1]
# access [69][2]
# access [69][3]
# access [69][4]
# access [69][5]
# access [69][6]
# access [69][7]
# access [69][8]
# access [69][9]
# access [69][10]
# access [69][11]
# access [69][12]
# access [69][13]
# access [69][14]
# access [69][15]
# access [69][16]
# access [69][17]
# access [69][18]
# access [69][19]
# access [69][20]
# access [69][21]
# access [69][22]
# access [69][23]
# access [69][24]
# access [69][25]
# access [69][26]
# access [69][27]
# access [69][28]
# access [69][29]
# access [69][30]
# access [69][31]
# access [69][32]
# access [69][33]
# access [69][34]
# access [69][35]
# access [69][36]
# access [69][37]
# access [69][38]
# access [69][39]
# access [69][40]
# access [69][41]
# access [69][42]
# access [69][43]
# access [69][44]
# access [69][45]
# access [69][46]
# access [69][47]
# access [69][48]
# access [69][49]
# access [69][50]
# access [69][51]
# access [69][52]
# access [69][53]
# access [69][54]
# access [69][55]
# access [70][0]
# access [70][1]
# access [70][2]
# access [70][3]
# access [70][4]
# access [70][5]
# access [70][6]
# access [70][7]
# access [70][8]
# access [70][9]
# access [71][0]
# access [71][1]
# access [71][2]
# access [71][3]
# access [71][4]
# access [71][5]
# access [71][6]
# access [71][7]
# access [71][8]
# access [71][9]
# access [71][10]
# access [71][11]
# access [71][12]
# access [71][13]
# access [71][14]
# access [71][15]
# access [71][16]
# access [71][17]
# access [71][18]
# access [71][19]
# access [71][20]
# access [71][21]
# access [71][22]
# access [71][23]
# access [72][0]
# access [72][1]
# access [72][2]
# access [72][3]
# access [72][4]
# access [72][5]
# access [72][6]
# access [72][7]
# access [72][8]
# access [72][9]
# access [72][10]
# access [72][11]
# access [72][12]
# access [72][13]
# access [72][14]
# access [72][15]
# access [72][16]
# access [72][17]
# access [72][18]
# access [72][19]
# access [72][20]
# access [72][21]
# access [72][22]
# access [72][23]
# access [72][24]
# access [72][25]
# access [72][26]
# access [72][27]
# access [72][28]
# access [72][29]
# access [72][30]
# access [72][31]
# access [72][32]
# access [72][33]
# access [73][0]
# access [73][1]
# access [73][2]
# access [73][3]
# access [73][4]
# access [73][5]
# access [73][6]
# access [73][7]
# access [73][8]
# access [73][9]
# access [74][0]
# access [74][1]
# access [74][2]
# access [74][3]
# access [74][4]
# access [74][5]
# access [74][6]
# access [74][7]
# access [74][8]
# access [74][9]
# access [74][10]
# access [75][0]
# access [75][1]
# access [75][2]
# access [75][3]
# access [75][4]
# access [75][5]
# access [75][6]
# access [75][7]
# access [75][8]
# access [75][9]
# access [75][10]
# access [75][11]
# access [75][12]
# access [75][13]
# access [75][14]
# access [75][15]
# access [75][16]
# access [75][17]
# access [75][18]
# access [75][19]
# access [75][20]
# access [75][21]
# access [75][22]
# access [75][23]
# access [76][0]
# access [76][1]
# access [76][2]
# access [76][3]
# access [76][4]
# access [76][5]
# access [76][6]
# access [76][7]
# access [76][8]
# access [76][9]
# access [76][10]
# access [76][11]
# access [76][12]
# access [76][13]
# access [76][14]
# access [76][15]
# access [76][16]
# access [76][17]
# access [76][18]
# access [76][19]
# access [76][20]
# access [76][21]
# access [76][22]
# access [76][23]
# access [76][24]
# access [76][25]
# access [77][0]
# access [77][1]
# access [77][2]
# access [77][3]
# access [77][4]
# access [77][5]
# access [77][6]
# access [77][7]
# access [77][8]
# access [77][9]
# access [77][10]
# access [77][11]
# access [77][12]
# access [77][13]
# access [77][14]
# access [77][15]
# access [77][16]
# access [77][17]
# access [77][18]
# access [78][0]
# access [78][1]
# access [78][2]
# access [78][3]
# access [78][4]
# access [78][5]
# access [78][6]
# access [78][7]
# access [78][8]
# access [78][9]
# access [78][10]
# access [78][11]
# access [78][12]
# access [78][13]
# access [78][14]
# access [78][15]
# access [78][16]
# access [79][0]
# access [79][1]
# access [79][2]
# access [79][3]
# access [79][4]
# access [79][5]
# access [79][6]
# access [79][7]
# access [79][8]
# access [79][9]
# access [79][10]
# access [79][11]
# access [80][0]
# access [80][1]
# access [80][2]
# access [80][3]
# access [80][4]
# access [80][5]
# access [80][6]
# access [80][7]
# access [80][8]
# access [81][0]
# access [81][1]
# access [81][2]
# access [81][3]
# access [81][4]
# access [81][5]
# access [81][6]
# access [81][7]
# access [81][8]
# access [81][9]
# access [82][0]
# access [82][1]
# access [82][2]
# access [82][3]
# access [82][4]
# access [82][5]
# access [82][6]
# access [82][7]
# access [82][8]
# access [82][9]
# access [82][10]
# access [83][0]
# access [83][1]
# access [83][2]
# access [83][3]
# access [83][4]
# access [83][5]
# access [83][6]
# access [83][7]
# access [83][8]
# access [83][9]
# access [83][10]
# access [83][11]
# access [83][12]
# access [83][13]
# access [83][14]
# access [83][15]
# access [83][16]
# access [83][17]
# access [83][18]
# access [84][0]
# access [84][1]
# access [84][2]
# access [84][3]
# access [84][4]
# access [84][5]
# access [84][6]
# access [84][7]
# access [84][8]
# access [84][9]
# access [85][0]
# access [85][1]
# access [85][2]
# access [85][3]
# access [85][4]
# access [85][5]
# access [85][6]
# access [85][7]
# access [85][8]
# access [85][9]
# access [85][10]
# access [85][11]
# access [85][12]
# access [85][13]
# access [85][14]
# access [85][15]
# access [85][16]
# access [85][17]
# access [85][18]
# access [85][19]
# access [85][20]
# access [85][21]
# access [85][22]
# access [85][23]
# access [85][24]
# access [85][25]
# access [85][26]
# access [85][27]
# access [85][28]
# access [86][0]
# access [86][1]
# access [86][2]
# access [86][3]
# access [86][4]
# access [86][5]
# access [86][6]
# access [86][7]
# access [86][8]
# access [86][9]
# access [86][10]
# access [86][11]
# access [86][12]
# access [86][13]
# access [86][14]
# access [86][15]
# access [86][16]
# access [86][17]
# access [86][18]
# access [86][19]
# access [86][20]
# access [86][21]
# access [86][22]
# access [86][23]
# access [86][24]
# access [86][25]
# access [86][26]
# access [86][27]
# access [86][28]
# access [86][29]
# access [86][30]
# access [86][31]
# access [86][32]
# access [86][33]
# access [87][0]
# access [87][1]
# access [87][2]
# access [87][3]
# access [87][4]
# access [87][5]
# access [87][6]
# access [87][7]
# access [87][8]
# access [87][9]
# access [87][10]
# access [87][11]
# access [87][12]
# access [87][13]
# access [87][14]
# access [87][15]
# access [87][16]
# access [87][17]
# access [87][18]
# access [87][19]
# access [87][20]
# access [87][21]
# access [87][22]
# access [87][23]
# access [87][24]
# access [87][25]
# access [88][0]
# access [88][1]
# access [88][2]
# access [88][3]
# access [88][4]
# access [88][5]
# access [88][6]
# access [88][7]
# access [88][8]
# access [88][9]
# access [88][10]
# access [88][11]
# access [88][12]
# access [88][13]
# access [89][0]
# access [89][1]
# access [89][2]
# access [89][3]
# access [89][4]
# access [89][5]
# access [89][6]
# access [89][7]
# access [89][8]
# access [89][9]
# access [89][10]
# access [89][11]
# access [89][12]
# access [89][13]
# access [89][14]
# access [89][15]
# access [89][16]
# access [89][17]
# access [89][18]
# access [89][19]
# access [89][20]
# access [89][21]
# access [89][22]
# access [89][23]
# access [89][24]
# access [89][25]
# access [89][26]
# access [89][27]
# access [89][28]
# access [89][29]
# access [89][30]
# access [89][31]
# access [90][0]
# access [90][1]
# access [90][2]
# access [90][3]
# access [90][4]
# access [90][5]
# access [90][6]
# access [90][7]
# access [90][8]
# access [90][9]
# access [90][10]
# access [90][11]
# access [91][0]
# access [91][1]
# access [91][2]
# access [91][3]
# access [91][4]
# access [91][5]
# access [91][6]
# access [91][7]
# access [91][8]
# access [91][9]
# access [91][10]
# access [91][11]
# access [92][0]
# access [92][1]
# access [92][2]
# access [92][3]
# access [92][4]
# access [92][5]
# access [92][6]
# access [92][7]
# access [92][8]
# access [92][9]
# access [92][10]
# access [92][11]
# access [92][12]
# access [92][13]
# access [92][14]
# access [92][15]
# access [92][16]
# access [93][0]
# access [93][1]
# access [93][2]
# access [93][3]
# access [93][4]
# access [93][5]
# access [93][6]
# access [93][7]
# access [93][8]
# access [93][9]
# access [93][10]
# access [93][11]
# access [93][12]
# access [94][0]
# access [94][1]
# access [94][2]
# access [94][3]
# access [94][4]
# access [94][5]
# access [94][6]
# access [94][7]
# access [94][8]
# access [94][9]
# access [94][10]
# access [94][11]
# access [94][12]
# access [94][13]
# access [94][14]
# access [94][15]
# access [94][16]
# access [94][17]
# access [94][18]
# access [94][19]
# access [94][20]
# access [94][21]
# access [94][22]
# access [94][23]
# access [94][24]
# access [94][25]
# access [94][26]
# access [94][27]
# access [94][28]
# access [94][29]
# access [94][30]
# access [95][0]
# access [95][1]
# access [95][2]
# access [95][3]
# access [95][4]
# access [95][5]
# access [95][6]
# access [95][7]
# access [95][8]
# access [95][9]
# access [95][10]
# access [95][11]
# access [95][12]
# access [95][13]
# access [95][14]
# access [96][0]
# access [96][1]
# access [96][2]
# access [96][3]
# access [96][4]
# access [96][5]
# access [96][6]
# access [96][7]
# access [96][8]
# access [96][9]
# access [96][10]
# access [96][11]
# access [96][12]
# access [96][13]
# access [96][14]
# access [96][15]
# access [96][16]
# access [97][0]
# access [97][1]
# access [97][2]
# access [97][3]
# access [97][4]
# access [97][5]
# access [97][6]
# access [97][7]
# access [97][8]
# access [97][9]
# access [98][0]
# access [98][1]
# access [98][2]
# access [98][3]
# access [98][4]
# access [98][5]
# access [98][6]
# access [98][7]
# access [98][8]
# access [98][9]
# access [98][10]
# access [98][11]
# access [98][12]
# access [98][13]
# access [98][14]
# access [98][15]
# access [98][16]
# access [98][17]
# access [98][18]
# access [98][19]
# access [98][20]
# access [98][21]
# access [98][22]
# access [98][23]
# access [98][24]
# access [98][25]
# access [98][26]
# access [98][27]
# access [98][28]
# access [98][29]
# access [98][30]
# access [98][31]
# access [98][32]
# access [98][33]
# access [98][34]
# access [98][35]
# access [98][36]
# access [98][37]
# access [98][38]
# access [98][39]
# access [98][40]
# access [98][41]
# access [98][42]
# access [98][43]
# access [98][44]
# access [98][45]
# access [98][46]
# access [99][0]
# access [99][1]
# access [99][2]
# access [99][3]
# access [99][4]
# access [99][5]
# access [99][6]
# access [99][7]
# access [99][8]
# access [99][9]
# access [99][10]
# access [99][11]
# access [99][12]
# access [99][13]
# access [99][14]
# access [99][15]
# access [99][16]
# access [99][17]
# access [99][18]
# access [99][19]
# access [99][20]
# access [99][21]
# access [99][22]
# access [99][23]
# access [99][24]
# access [99][25]
# access [99][26]
# access [99][27]
# access [99][28]
# access [99][29]
# access [99][30]
# access [99][31]
# access [99][32]
# access [99][33]
# access [99][34]
# access [99][35]
# access [99][36]
# access [99][37]
# access [99][38]
# access [99][39]
# access [99][40]
# access [99][41]
# access [99][42]
# access [100][0]
# access [100][1]
# access [100][2]
# access [100][3]
# access [100][4]
# access [100][5]
# access [100][6]
# access [100][7]
# access [100][8]
# access [100][9]
# access [100][10]
# access [101][0]
# access [101][1]
# access [101][2]
# access [101][3]
# access [101][4]
# access [101][5]
# access [101][6]
# access [101][7]
# access [101][8]
# access [101][9]
# access [101][10]
# access [101][11]
# access [101][12]
# access [101][13]
# access [102][0]
# access [102][1]
# access [102][2]
# access [102][3]
# access [102][4]
# access [102][5]
# access [102][6]
# access [102][7]
# access [102][8]
# access [102][9]
# access [102][10]
# access [102][11]
# access [102][12]
# access [102][13]
# access [102][14]
# access [102][15]
# access [102][16]
# access [102][17]
# access [102][18]
# access [102][19]
# access [103][0]
# access [103][1]
# access [103][2]
# access [103][3]
# access [103][4]
# access [103][5]
# access [103][6]
# access [103][7]
# access [103][8]
# access [103][9]
# access [103][10]
# access [103][11]
# access [103][12]
# access [103][13]
# access [103][14]
# access [103][15]
# access [103][16]
# access [103][17]
# access [103][18]
# access [103][19]
# access [103][20]
# access [103][21]
# access [103][22]
# access [103][23]
# access [103][24]
# access [103][25]
# access [103][26]
# access [103][27]
# access [103][28]
# access [103][29]
# access [103][30]
# access [103][31]
# access [103][32]
# access [104][0]
# access [104][1]
# access [104][2]
# access [104][3]
# access [104][4]
# access [104][5]
# access [104][6]
# access [104][7]
# access [104][8]
# access [104][9]
# access [104][10]
# access [104][11]
# access [104][12]
# access [104][13]
# access [104][14]
# access [104][15]
# access [104][16]
# access [104][17]
# access [104][18]
# access [104][19]
# access [104][20]
# access [104][21]
# access [105][0]
# access [105][1]
# access [105][2]
# access [105][3]
# access [105][4]
# access [105][5]
# access [105][6]
# access [105][7]
# access [105][8]
# access [105][9]
# access [105][10]
# access [105][11]
# access [106][0]
# access [106][1]
# access [106][2]
# access [106][3]
# access [106][4]
# access [106][5]
# access [106][6]
# access [106][7]
# access [106][8]
# access [106][9]
# access [106][10]
# access [106][11]
# access [106][12]
# access [106][13]
# access [106][14]
# access [106][15]
# access [106][16]
# access [106][17]
# access [106][18]
# access [106][19]
# access [106][20]
# access [106][21]
# access [106][22]
# access [106][23]
# access [106][24]
# access [106][25]
# access [106][26]
# access [106][27]
# access [106][28]
# access [106][29]
# access [106][30]
# access [106][31]
# access [106][32]
# access [106][33]
# access [107][0]
# access [107][1]
# access [107][2]
# access [107][3]
# access [107][4]
# access [107][5]
# access [107][6]
# access [107][7]
# access [107][8]
# access [107][9]
# access [107][10]
# access [107][11]
# access [107][12]
# access [107][13]
# access [107][14]
# access [107][15]
# access [107][16]
# access [107][17]
# access [107][18]
# access [107][19]
# access [107][20]
# access [107][21]
# access [107][22]
# access [107][23]
# access [107][24]
# access [107][25]
# access [107][26]
# access [107][27]
# access [107][28]
# access [107][29]
# access [107][30]
# access [107][31]
# access [107][32]
# access [107][33]
# access [107][34]
# access [107][35]
# access [107][36]
# access [107][37]
# access [107][38]
# access [108][0]
# access [108][1]
# access [108][2]
# access [108][3]
# access [108][4]
# access [108][5]
# access [108][6]
# access [108][7]
# access [108][8]
# access [108][9]
# access [108][10]
# access [108][11]
# access [108][12]
# access [108][13]
# access [108][14]
# access [108][15]
# access [108][16]
# access [108][17]
# access [108][18]
# access [108][19]
# access [108][20]
# access [108][21]
# access [108][22]
# access [108][23]
# access [108][24]
# access [108][25]
# access [108][26]
# access [108][27]
# access [108][28]
# access [108][29]
# access [108][30]
# access [108][31]
# access [108][32]
# access [108][33]
# access [108][34]
# access [108][35]
# access [108][36]
# access [108][37]
# access [108][38]
# access [108][39]
# access [108][40]
# access [108][41]
# access [108][42]
# access [108][43]
# access [108][44]
# access [108][45]
# access [108][46]
# access [108][47]
# access [108][48]
# access [108][49]
# access [109][0]
# access [109][1]
# access [109][2]
# access [109][3]
# access [109][4]
# access [109][5]
# access [109][6]
# access [109][7]
# access [109][8]
# access [109][9]
# access [109][10]
# access [109][11]
# access [109][12]
# access [109][13]
# access [109][14]
# access [110][0]
# access [110][1]
# access [110][2]
# access [110][3]
# access [110][4]
# access [110][5]
# access [110][6]
# access [110][7]
# access [110][8]
# access [110][9]
# access [110][10]
# access [110][11]
# access [110][12]
# access [110][13]
# access [110][14]
# access [110][15]
# access [110][16]
# access [110][17]
# access [110][18]
# access [110][19]
# access [110][20]
# access [110][21]
# access [110][22]
# access [110][23]
# access [110][24]
# access [110][25]
# access [110][26]
# access [110][27]
# access [110][28]
# access [110][29]
# access [110][30]
# access [110][31]
# access [110][32]
# access [110][33]
# access [110][34]
# access [110][35]
# access [110][36]
# access [110][37]
# access [110][38]
# access [110][39]
# access [110][40]
# access [111][0]
# access [111][1]
# access [111][2]
# access [111][3]
# access [111][4]
# access [111][5]
# access [111][6]
# access [111][7]
# access [111][8]
# access [111][9]
# access [111][10]
# access [111][11]
# access [111][12]
# access [111][13]
# access [111][14]
# access [111][15]
# access [111][16]
# access [111][17]
# access [111][18]
# access [112][0]
# access [112][1]
# access [112][2]
# access [112][3]
# access [112][4]
# access [112][5]
# access [112][6]
# access [112][7]
# access [112][8]
# access [112][9]
# access [112][10]
# access [112][11]
# access [112][12]
# access [112][13]
# access [112][14]
# access [112][15]
# access [112][16]
# access [112][17]
# access [112][18]
# access [113][0]
# access [113][1]
# access [113][2]
# access [113][3]
# access [113][4]
# access [113][5]
# access [113][6]
# access [113][7]
# access [113][8]
# access [113][9]
# access [113][10]
# access [113][11]
# access [113][12]
# access [113][13]
# access [113][14]
# access [113][15]
# access [113][16]
# access [113][17]
# access [113][18]
# access [113][19]
# access [113][20]
# access [113][21]
# access [113][22]
# access [113][23]
# access [113][24]
# access [113][25]
# access [114][0]
# access [114][1]
# access [114][2]
# access [114][3]
# access [114][4]
# access [114][5]
# access [114][6]
# access [114][7]
# access [114][8]
# access [114][9]
# access [114][10]
# access [114][11]
# access [114][12]
# access [115][0]
# access [115][1]
# access [115][2]
# access [115][3]
# access [115][4]
# access [115][5]
# access [115][6]
# access [115][7]
# access [115][8]
# access [115][9]
# access [115][10]
# access [115][11]
# access [116][0]
# access [116][1]
# access [116][2]
# access [116][3]
# access [116][4]
# access [116][5]
# access [116][6]
# access [116][7]
# access [116][8]
# access [116][9]
# access [116][10]
# access [116][11]
# access [116][12]
# access [116][13]
# access [116][14]
# access [116][15]
# access [117][0]
# access [117][1]
# access [117][2]
# access [117][3]
# access [117][4]
# access [117][5]
# access [117][6]
# access [117][7]
# access [117][8]
# access [118][0]
# access [118][1]
# access [118][2]
# access [118][3]
# access [118][4]
# access [118][5]
# access [118][6]
# access [118][7]
# access [118][8]
# access [118][9]
# access [118][10]
# access [118][11]
# access [118][12]
# access [118][13]
# access [118][14]
# access [118][15]
# access [118][16]
# access [118][17]
# access [118][18]
# access [118][19]
# access [118][20]
# access [118][21]
# access [118][22]
# access [118][23]
# access [119][0]
# access [119][1]
# access [119][2]
# access [119][3]
# access [119][4]
# access [119][5]
# access [119][6]
# access [119][7]
# access [119][8]
# access [119][9]
# access [119][10]
# access [119][11]
# access [119][12]
# access [119][13]
# access [119][14]
# access [119][15]
# access [119][16]
# access [119][17]
# access [120][0]
# access [120][1]
# access [120][2]
# access [120][3]
# access [120][4]
# access [120][5]
# access [120][6]
# access [120][7]
# access [120][8]
# access [120][9]
# access [120][10]
# access [120][11]
# access [120][12]
# access [120][13]
# access [120][14]
# access [121][0]
# access [121][1]
# access [121][2]
# access [121][3]
# access [121][4]
# access [121][5]
# access [121][6]
# access [121][7]
# access [121][8]
# access [121][9]
# access [121][10]
# access [121][11]
# access [121][12]
# access [121][13]
# access [121][14]
# access [121][15]
# access [121][16]
# access [121][17]
# access [121][18]
# access [121][19]
# access [121][20]
# access [121][21]
# access [122][0]
# access [122][1]
# access [122][2]
# access [122][3]
# access [122][4]
# access [122][5]
# access [122][6]
# access [122][7]
# access [122][8]
# access [122][9]
# access [122][10]
# access [122][11]
# access [122][12]
# access [122][13]
# access [122][14]
# access [122][15]
# access [122][16]
# access [122][17]
# access [122][18]
# access [122][19]
# access [122][20]
# access [122][21]
# access [122][22]
# access [122][23]
# access [122][24]
# access [122][25]
# access [122][26]
# access [122][27]
# access [122][28]
# access [122][29]
# access [122][30]
# access [122][31]
# access [122][32]
# access [122][33]
# access [122][34]
# access [122][35]
# access [122][36]
# access [122][37]
# access [122][38]
# access [122][39]
# access [122][40]
# access [122][41]
# access [122][42]
# access [122][43]
# access [122][44]
# access [122][45]
# access [122][46]
# access [122][47]
# access [122][48]
# access [122][49]
# access [122][50]
# access [122][51]
# access [123][0]
# access [123][1]
# access [123][2]
# access [123][3]
# access [123][4]
# access [123][5]
# access [123][6]
# access [123][7]
# access [123][8]
# access [123][9]
# access [123][10]
# access [123][11]
# access [123][12]
# access [123][13]
# access [123][14]
# access [123][15]
# access [123][16]
# access [123][17]
# access [123][18]
# access [123][19]
# access [123][20]
# access [123][21]
# access [123][22]
# access [123][23]
# access [123][24]
# access [123][25]
# access [123][26]
# access [123][27]
# access [123][28]
# access [123][29]
# access [123][30]
# access [123][31]
# access [123][32]
# access [123][33]
# access [123][34]
# access [123][35]
# access [123][36]
# access [124][0]
# access [124][1]
# access [124][2]
# access [124][3]
# access [124][4]
# access [124][5]
# access [124][6]
# access [124][7]
# access [124][8]
# access [124][9]
# access [124][10]
# access [124][11]
# access [124][12]
# access [124][13]
# access [124][14]
# access [124][15]
# access [124][16]
# access [124][17]
# access [124][18]
# access [124][19]
# access [124][20]
# access [124][21]
# access [124][22]
# access [124][23]
# access [124][24]
# access [125][0]
# access [125][1]
# access [125][2]
# access [125][3]
# access [125][4]
# access [125][5]
# access [125][6]
# access [125][7]
# access [125][8]
# access [125][9]
# access [125][10]
# access [125][11]
# access [125][12]
# access [125][13]
# access [125][14]
# access [125][15]
# access [125][16]
# access [125][17]
# access [125][18]
# access [125][19]
# access [125][20]
# access [125][21]
# access [125][22]
# access [125][23]
# access [125][24]
# access [125][25]
# access [125][26]
# access [125][27]
# access [125][28]
# access [125][29]
# access [126][0]
# access [126][1]
# access [126][2]
# access [126][3]
# access [126][4]
# access [126][5]
# access [126][6]
# access [126][7]
# access [126][8]
# access [126][9]
# access [126][10]
# access [126][11]
# access [126][12]
# access [126][13]
# access [126][14]
# access [126][15]
# access [126][16]
# access [126][17]
# access [126][18]
# access [126][19]
# access [126][20]
# access [126][21]
# access [126][22]
# access [126][23]
# access [126][24]
# access [126][25]
# access [126][26]
# access [126][27]
# access [126][28]
# ...
# access [2007][16]
# access [2007][17]
# access [2007][18]
# access [2007][19]
# access [2007][20]
# access [2007][21]
# access [2007][22]
# access [2007][23]
# access [2008][0]
# access [2008][1]
# access [2008][2]
# access [2008][3]
# access [2008][4]
# access [2008][5]
# access [2008][6]
# access [2008][7]
# access [2008][8]
# access [2008][9]
# access [2008][10]
# access [2008][11]
# access [2008][12]
# access [2008][13]
# access [2008][14]
# access [2008][15]
# access [2008][16]
# access [2008][17]
# access [2008][18]
# access [2008][19]
# access [2008][20]
# access [2008][21]
# access [2008][22]
# access [2009][0]
# access [2009][1]
# access [2009][2]
# access [2009][3]
# access [2009][4]
# access [2009][5]
# access [2009][6]
# access [2009][7]
# access [2010][0]
# access [2010][1]
# access [2010][2]
# access [2010][3]
# access [2010][4]
# access [2010][5]
# access [2010][6]
# access [2010][7]
# access [2010][8]
# access [2010][9]
# access [2010][10]
# access [2010][11]
# access [2011][0]
# access [2011][1]
# access [2011][2]
# access [2011][3]
# access [2011][4]
# access [2011][5]
# access [2011][6]
# access [2011][7]
# access [2011][8]
# access [2011][9]
# access [2011][10]
# access [2011][11]
# access [2011][12]
# access [2011][13]
# access [2011][14]
# access [2011][15]
# access [2011][16]
# access [2011][17]
# access [2011][18]
# access [2012][0]
# access [2012][1]
# access [2012][2]
# access [2013][0]
# access [2013][1]
# access [2013][2]
# access [2013][3]
# access [2013][4]
# access [2013][5]
# access [2013][6]
# access [2013][7]
# access [2013][8]
# access [2013][9]
# access [2013][10]
# access [2013][11]
# access [2013][12]
# access [2013][13]
# access [2013][14]
# access [2013][15]
# access [2013][16]
# access [2013][17]
# access [2013][18]
# access [2013][19]
# access [2013][20]
# access [2013][21]
# access [2014][0]
# access [2014][1]
# access [2014][2]
# access [2014][3]
# access [2014][4]
# access [2014][5]
# access [2014][6]
# access [2014][7]
# access [2014][8]
# access [2014][9]
# access [2014][10]
# access [2014][11]
# access [2014][12]
# access [2014][13]
# access [2014][14]
# access [2014][15]
# access [2014][16]
# access [2014][17]
# access [2014][18]
# access [2014][19]
# access [2014][20]
# access [2015][0]
# access [2015][1]
# access [2015][2]
# access [2015][3]
# access [2015][4]
# access [2015][5]
# access [2015][6]
# access [2015][7]
# access [2015][8]
# access [2015][9]
# access [2015][10]
# access [2015][11]
# access [2015][12]
# access [2015][13]
# access [2015][14]
# access [2015][15]
# access [2015][16]
# access [2015][17]
# access [2015][18]
# access [2015][19]
# access [2015][20]
# access [2015][21]
# access [2015][22]
# access [2015][23]
# access [2015][24]
# access [2016][0]
# access [2016][1]
# access [2016][2]
# access [2016][3]
# access [2016][4]
# access [2016][5]
# access [2016][6]
# access [2016][7]
# access [2017][0]
# access [2017][1]
# access [2017][2]
# access [2017][3]
# access [2017][4]
# access [2017][5]
# access [2017][6]
# access [2017][7]
# access [2017][8]
# access [2017][9]
# access [2017][10]
# access [2017][11]
# access [2017][12]
# access [2017][13]
# access [2017][14]
# access [2017][15]
# access [2017][16]
# access [2017][17]
# access [2017][18]
# access [2017][19]
# access [2017][20]
# access [2017][21]
# access [2017][22]
# access [2018][0]
# access [2018][1]
# access [2018][2]
# access [2018][3]
# access [2018][4]
# access [2018][5]
# access [2018][6]
# access [2019][0]
# access [2019][1]
# access [2019][2]
# access [2019][3]
# access [2019][4]
# access [2019][5]
# access [2019][6]
# access [2020][0]
# access [2020][1]
# access [2020][2]
# access [2020][3]
# access [2020][4]
# access [2020][5]
# access [2020][6]
# access [2020][7]
# access [2020][8]
# access [2020][9]
# access [2020][10]
# access [2020][11]
# access [2020][12]
# access [2021][0]
# access [2021][1]
# access [2021][2]
# access [2021][3]
# access [2021][4]
# access [2022][0]
# access [2022][1]
# access [2022][2]
# access [2022][3]
# access [2022][4]
# access [2022][5]
# access [2022][6]
# access [2022][7]
# access [2022][8]
# access [2022][9]
# access [2022][10]
# access [2022][11]
# access [2022][12]
# access [2023][0]
# access [2023][1]
# access [2023][2]
# access [2023][3]
# access [2023][4]
# access [2023][5]
# access [2023][6]
# access [2023][7]
# access [2023][8]
# access [2023][9]
# access [2023][10]
# access [2023][11]
# access [2023][12]
# access [2023][13]
# access [2023][14]
# access [2023][15]
# access [2024][0]
# access [2024][1]
# access [2024][2]
# access [2024][3]
# access [2024][4]
# access [2024][5]
# access [2024][6]
# access [2024][7]
# access [2024][8]
# access [2024][9]
# access [2024][10]
# access [2024][11]
# access [2024][12]
# access [2024][13]
# access [2024][14]
# access [2025][0]
# access [2025][1]
# access [2025][2]
# access [2025][3]
# access [2025][4]
# access [2025][5]
# access [2025][6]
# access [2025][7]
# access [2025][8]
# access [2025][9]
# access [2025][10]
# access [2025][11]
# access [2025][12]
# access [2025][13]
# access [2025][14]
# access [2025][15]
# access [2025][16]
# access [2025][17]
# access [2025][18]
# access [2025][19]
# access [2025][20]
# access [2026][0]
# access [2026][1]
# access [2026][2]
# access [2026][3]
# access [2026][4]
# access [2026][5]
# access [2026][6]
# access [2026][7]
# access [2026][8]
# access [2026][9]
# access [2026][10]
# access [2026][11]
# access [2026][12]
# access [2026][13]
# access [2026][14]
# access [2026][15]
# access [2027][0]
# access [2027][1]
# access [2027][2]
# access [2028][0]
# access [2028][1]
# access [2028][2]
# access [2028][3]
# access [2028][4]
# access [2028][5]
# access [2028][6]
# access [2028][7]
# access [2028][8]
# access [2028][9]
# access [2028][10]
# access [2028][11]
# access [2028][12]
# access [2029][0]
# access [2029][1]
# access [2029][2]
# access [2029][3]
# access [2029][4]
# access [2029][5]
# access [2029][6]
# access [2029][7]
# access [2029][8]
# access [2029][9]
# access [2029][10]
# access [2029][11]
# access [2029][12]
# access [2029][13]
# access [2029][14]
# access [2029][15]
# access [2029][16]
# access [2030][0]
# access [2030][1]
# access [2030][2]
# access [2030][3]
# access [2030][4]
# access [2030][5]
# access [2030][6]
# access [2030][7]
# access [2030][8]
# access [2030][9]
# access [2030][10]
# access [2030][11]
# access [2030][12]
# access [2030][13]
# access [2030][14]
# access [2030][15]
# access [2030][16]
# access [2031][0]
# access [2031][1]
# access [2031][2]
# access [2031][3]
# access [2031][4]
# access [2032][0]
# access [2032][1]
# access [2032][2]
# access [2032][3]
# access [2032][4]
# access [2032][5]
# access [2032][6]
# access [2032][7]
# access [2032][8]
# access [2032][9]
# access [2032][10]
# access [2032][11]
# access [2032][12]
# access [2032][13]
# access [2032][14]
# access [2032][15]
# access [2032][16]
# access [2032][17]
# access [2032][18]
# access [2032][19]
# access [2032][20]
# access [2032][21]
# access [2032][22]
# access [2032][23]
# access [2032][24]
# access [2032][25]
# access [2032][26]
# access [2033][0]
# access [2033][1]
# access [2033][2]
# access [2033][3]
# access [2033][4]
# access [2034][0]
# access [2034][1]
# access [2034][2]
# access [2034][3]
# access [2034][4]
# access [2034][5]
# access [2034][6]
# access [2035][0]
# access [2035][1]
# access [2035][2]
# access [2035][3]
# access [2036][0]
# access [2036][1]
# access [2036][2]
# access [2036][3]
# access [2036][4]
# access [2036][5]
# access [2036][6]
# access [2036][7]
# access [2036][8]
# access [2037][0]
# access [2037][1]
# access [2037][2]
# access [2037][3]
# access [2037][4]
# access [2037][5]
# access [2037][6]
# access [2037][7]
# access [2037][8]
# access [2037][9]
# access [2037][10]
# access [2037][11]
# access [2037][12]
# access [2037][13]
# access [2037][14]
# access [2037][15]
# access [2037][16]
# access [2037][17]
# access [2037][18]
# access [2038][0]
# access [2038][1]
# access [2038][2]
# access [2038][3]
# access [2038][4]
# access [2038][5]
# access [2038][6]
# access [2038][7]
# access [2038][8]
# access [2038][9]
# access [2038][10]
# access [2038][11]
# access [2039][0]
# access [2039][1]
# access [2039][2]
# access [2039][3]
# access [2039][4]
# access [2039][5]
# access [2039][6]
# access [2039][7]
# access [2039][8]
# access [2039][9]
# access [2039][10]
# access [2039][11]
# access [2039][12]
# access [2039][13]
# access [2039][14]
# access [2039][15]
# access [2039][16]
# access [2039][17]
# access [2039][18]
# access [2039][19]
# access [2039][20]
# access [2039][21]
# access [2039][22]
# access [2039][23]
# access [2039][24]
# access [2039][25]
# access [2040][0]
# access [2040][1]
# access [2040][2]
# access [2040][3]
# access [2040][4]
# access [2041][0]
# access [2041][1]
# access [2041][2]
# access [2041][3]
# access [2041][4]
# access [2041][5]
# access [2041][6]
# access [2041][7]
# access [2041][8]
# access [2041][9]
# access [2041][10]
# access [2041][11]
# access [2041][12]
# access [2041][13]
# access [2041][14]
# access [2042][0]
# access [2042][1]
# access [2042][2]
# access [2042][3]
# access [2042][4]
# access [2042][5]
# access [2042][6]
# access [2042][7]
# access [2042][8]
# access [2042][9]
# access [2042][10]
# access [2042][11]
# access [2042][12]
# access [2042][13]
# access [2042][14]
# access [2042][15]
# access [2042][16]
# access [2042][17]
# access [2042][18]
# access [2043][0]
# access [2043][1]
# access [2043][2]
# access [2043][3]
# access [2043][4]
# access [2043][5]
# access [2043][6]
# access [2043][7]
# access [2043][8]
# access [2043][9]
# access [2043][10]
# access [2043][11]
# access [2043][12]
# access [2043][13]
# access [2043][14]
# access [2043][15]
# access [2044][0]
# access [2044][1]
# access [2044][2]
# access [2044][3]
# access [2044][4]
# access [2044][5]
# access [2044][6]
# access [2044][7]
# access [2044][8]
# access [2044][9]
# access [2044][10]
# access [2044][11]
# access [2044][12]
# access [2044][13]
# access [2044][14]
# access [2045][0]
# access [2045][1]
# access [2045][2]
# access [2045][3]
# access [2045][4]
# access [2045][5]
# access [2045][6]
# access [2045][7]
# access [2045][8]
# access [2045][9]
# access [2045][10]
# access [2045][11]
# access [2045][12]
# access [2045][13]
# access [2045][14]
# access [2045][15]
# access [2045][16]
# access [2045][17]
# access [2045][18]
# access [2046][0]
# access [2046][1]
# access [2046][2]
# access [2046][3]
# access [2046][4]
# access [2046][5]
# access [2046][6]
# access [2046][7]
# access [2046][8]
# access [2046][9]
# access [2046][10]
# access [2046][11]
# access [2046][12]
# access [2046][13]
# access [2047][0]
# access [2047][1]
# access [2047][2]
# access [2048][0]
# access [2048][1]
# access [2048][2]
# access [2048][3]
# access [2048][4]
# access [2048][5]
# access [2048][6]
# access [2048][7]
# access [2048][8]
# access [2048][9]
# access [2049][0]
# access [2049][1]
# access [2049][2]
# access [2049][3]
# access [2049][4]
# access [2049][5]
# access [2049][6]
# access [2049][7]
# access [2049][8]
# access [2049][9]
# access [2049][10]
# access [2049][11]
# access [2049][12]
# access [2049][13]
# access [2049][14]
# access [2049][15]
# access [2050][0]
# access [2050][1]
# access [2050][2]
# access [2050][3]
# access [2050][4]
# access [2050][5]
# access [2050][6]
# access [2050][7]
# access [2050][8]
# access [2050][9]
# access [2050][10]
# access [2050][11]
# access [2050][12]
# access [2050][13]
# access [2050][14]
# access [2050][15]
# access [2050][16]
# access [2050][17]
# access [2050][18]
# access [2050][19]
# access [2050][20]
# access [2050][21]
# access [2050][22]
# access [2050][23]
# access [2050][24]
# access [2050][25]
# access [2050][26]
# access [2050][27]
# access [2051][0]
# access [2051][1]
# access [2051][2]
# access [2051][3]
# access [2051][4]
# access [2051][5]
# access [2051][6]
# access [2051][7]
# access [2051][8]
# access [2051][9]
# access [2051][10]
# access [2051][11]
# access [2051][12]
# access [2051][13]
# access [2051][14]
# access [2051][15]
# access [2051][16]
# access [2051][17]
# access [2051][18]
# access [2051][19]
# access [2051][20]
# access [2051][21]
# access [2051][22]
# access [2051][23]
# access [2051][24]
# access [2051][25]
# access [2051][26]
# access [2051][27]
# access [2051][28]
# access [2051][29]
# access [2051][30]
# access [2051][31]
# access [2051][32]
# access [2051][33]
# access [2051][34]
# access [2051][35]
# access [2051][36]
# access [2052][0]
# access [2052][1]
# access [2052][2]
# access [2052][3]
# access [2052][4]
# access [2052][5]
# access [2052][6]
# access [2052][7]
# access [2052][8]
# access [2052][9]
# access [2052][10]
# access [2052][11]
# access [2052][12]
# access [2052][13]
# access [2052][14]
# access [2052][15]
# access [2052][16]
# access [2052][17]
# access [2052][18]
# access [2052][19]
# access [2052][20]
# access [2052][21]
# access [2052][22]
# access [2052][23]
# access [2053][0]
# access [2053][1]
# access [2053][2]
# access [2053][3]
# access [2053][4]
# access [2053][5]
# access [2053][6]
# access [2053][7]
# access [2053][8]
# access [2053][9]
# access [2053][10]
# access [2053][11]
# access [2053][12]
# access [2053][13]
# access [2054][0]
# access [2054][1]
# access [2054][2]
# access [2054][3]
# access [2054][4]
# access [2054][5]
# access [2054][6]
# access [2054][7]
# access [2054][8]
# access [2054][9]
# access [2054][10]
# access [2054][11]
# access [2054][12]
# access [2054][13]
# access [2054][14]
# access [2054][15]
# access [2054][16]
# access [2054][17]
# access [2055][0]
# access [2055][1]
# access [2055][2]
# access [2055][3]
# access [2055][4]
# access [2055][5]
# access [2055][6]
# access [2055][7]
# access [2055][8]
# access [2055][9]
# access [2055][10]
# access [2055][11]
# access [2055][12]
# access [2055][13]
# access [2055][14]
# access [2055][15]
# access [2055][16]
# access [2055][17]
# access [2055][18]
# access [2056][0]
# access [2056][1]
# access [2056][2]
# access [2056][3]
# access [2056][4]
# access [2056][5]
# access [2056][6]
# access [2056][7]
# access [2056][8]
# access [2056][9]
# access [2056][10]
# access [2056][11]
# access [2056][12]
# access [2056][13]
# access [2056][14]
# access [2057][0]
# access [2057][1]
# access [2057][2]
# access [2057][3]
# access [2057][4]
# access [2057][5]
# access [2057][6]
# access [2057][7]
# access [2057][8]
# access [2057][9]
# access [2057][10]
# access [2057][11]
# access [2057][12]
# access [2057][13]
# access [2058][0]
# access [2058][1]
# access [2058][2]
# access [2058][3]
# access [2058][4]
# access [2058][5]
# access [2058][6]
# access [2058][7]
# access [2058][8]
# access [2058][9]
# access [2058][10]
# access [2059][0]
# access [2059][1]
# access [2059][2]
# access [2059][3]
# access [2059][4]
# access [2059][5]
# access [2059][6]
# access [2059][7]
# access [2059][8]
# access [2059][9]
# access [2059][10]
# access [2059][11]
# access [2059][12]
# access [2059][13]
# access [2059][14]
# access [2059][15]
# access [2059][16]
# access [2059][17]
# access [2059][18]
# access [2059][19]
# access [2059][20]
# access [2059][21]
# access [2059][22]
# access [2059][23]
# access [2059][24]
# access [2059][25]
# access [2059][26]
# access [2059][27]
# access [2059][28]
# access [2059][29]
# access [2059][30]
# access [2059][31]
# access [2059][32]
# access [2059][33]
# access [2059][34]
# access [2059][35]
# access [2059][36]
# access [2059][37]
# access [2059][38]
# access [2060][0]
# access [2060][1]
# access [2060][2]
# access [2060][3]
# access [2060][4]
# access [2060][5]
# access [2060][6]
# access [2060][7]
# access [2060][8]
# access [2060][9]
# access [2060][10]
# access [2060][11]
# access [2060][12]
# access [2060][13]
# access [2060][14]
# access [2060][15]
# access [2060][16]
# access [2060][17]
# access [2060][18]
# access [2060][19]
# access [2060][20]
# access [2060][21]
# access [2060][22]
# access [2060][23]
# access [2060][24]
# access [2060][25]
# access [2060][26]
# access [2060][27]
# access [2060][28]
# access [2060][29]
# access [2060][30]
# access [2060][31]
# access [2060][32]
# access [2060][33]
# access [2060][34]
# access [2060][35]
# access [2060][36]
# access [2060][37]
# access [2060][38]
# access [2060][39]
# access [2060][40]
# access [2061][0]
# access [2061][1]
# access [2061][2]
# access [2061][3]
# access [2061][4]
# access [2061][5]
# access [2061][6]
# access [2061][7]
# access [2061][8]
# access [2061][9]
# access [2061][10]
# access [2061][11]
# access [2061][12]
# access [2061][13]
# access [2061][14]
# access [2061][15]
# access [2061][16]
# access [2061][17]
# access [2061][18]
# access [2061][19]
# access [2061][20]
# access [2062][0]
# access [2062][1]
# access [2062][2]
# access [2062][3]
# access [2062][4]
# access [2062][5]
# access [2062][6]
# access [2062][7]
# access [2062][8]
# access [2062][9]
# access [2062][10]
# access [2062][11]
# access [2062][12]
# access [2062][13]
# access [2062][14]
# access [2062][15]
# access [2062][16]
# access [2062][17]
# access [2062][18]
# access [2062][19]
# access [2062][20]
# access [2062][21]
# access [2062][22]
# access [2062][23]
# access [2062][24]
# access [2062][25]
# access [2062][26]
# access [2062][27]
# access [2062][28]
# access [2062][29]
# access [2062][30]
# access [2062][31]
# access [2062][32]
# access [2063][0]
# access [2063][1]
# access [2063][2]
# access [2063][3]
# access [2063][4]
# access [2063][5]
# access [2063][6]
# access [2063][7]
# access [2063][8]
# access [2063][9]
# access [2063][10]
# access [2063][11]
# access [2063][12]
# access [2063][13]
# access [2063][14]
# access [2063][15]
# access [2063][16]
# access [2063][17]
# access [2063][18]
# access [2063][19]
# access [2063][20]

# %%
data_test
# Out:
#            Sentence #     Word  Tag     Dictionary
# 0         Sentence: 1       มา    O             NO
# 1         Sentence: 1      พูด    O             NO
# 2         Sentence: 1      คุย    O             NO
# 3         Sentence: 1      กัน    O             NO
# 4         Sentence: 1      ถึง    O             NO
# ...               ...      ...  ...            ...
# 36377  Sentence: 2064      และ  org  location_name
# 36378  Sentence: 2064    ประมง  org             NO
# 36379  Sentence: 2064     ทะเล  org             NO
# 36380  Sentence: 2064  จังหวัด    O             NO
# 36381  Sentence: 2064   ภูเก็ต  loc  location_name
#
# [36382 rows x 4 columns]

# %%
split_all_tag( data_test )

# %%
data_test
# Out:
#            Sentence #     Word       Tag     Dictionary
# 0         Sentence: 1       มา         O             NO
# 1         Sentence: 1      พูด         O             NO
# 2         Sentence: 1      คุย         O             NO
# 3         Sentence: 1      กัน         O             NO
# 4         Sentence: 1      ถึง         O             NO
# ...               ...      ...       ...            ...
# 36377  Sentence: 2064      และ  org_cont  location_name
# 36378  Sentence: 2064    ประมง  org_cont             NO
# 36379  Sentence: 2064     ทะเล   org_end             NO
# 36380  Sentence: 2064  จังหวัด         O             NO
# 36381  Sentence: 2064   ภูเก็ต       loc  location_name
#
# [36382 rows x 4 columns]
